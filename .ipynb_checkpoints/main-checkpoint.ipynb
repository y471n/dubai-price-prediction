# %%
# !gdown 1jxSR9Cov4XaTXY1kPUnMFk7MaXR-bcQ5

# %%
FILE_PATH = 'Transactions.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pywaffle import Waffle
import numpy as np
pd.set_option('display.float_format', '{:,.5f}'.format)

# %%
def format_num(num):
  return "{:,}".format(num)

def df_status(df):
    print(f"{format_num(len(df))} Samples & {len(df.columns)} Features")

# %%
df = pd.read_csv(FILE_PATH)

# %%
df.columns
df.head()
# Out:
#    transaction_id  procedure_id  trans_group_id trans_group_ar trans_group_en  \
# 0    3-9-2006-163             9               3           هبات          Gifts
# 1   3-9-2019-2944             9               3           هبات          Gifts
# 2   2-13-1999-347            13               2           رهون      Mortgages
# 3   2-13-2001-547            13               2           رهون      Mortgages
# 4  2-13-2020-9477            13               2           رهون      Mortgages
#
#   procedure_name_ar      procedure_name_en instance_date  property_type_id  \
# 0               هبه                  Grant    16-10-2006                 4
# 1               هبه                  Grant    13-11-2019                 1
# 2         تسجيل رهن  Mortgage Registration    22-03-1999                 1
# 3         تسجيل رهن  Mortgage Registration    23-07-2001                 2
# 4         تسجيل رهن  Mortgage Registration    30-11-2020                 2
#
#   property_type_ar  ... rooms_en  has_parking procedure_area     actual_worth  \
# 0             فيلا  ...      NaN            0    3,162.42000 12,000,000.00000
# 1              أرض  ...      NaN            0      209.09000    916,659.00000
# 2              أرض  ...      NaN            0    1,062.72000  1,200,000.00000
# 3             مبنى  ...      NaN            0    1,393.55000  3,500,000.00000
# 4             مبنى  ...      NaN            0      278.71000  2,500,000.00000
#
#   meter_sale_price rent_value  meter_rent_price no_of_parties_role_1  \
# 0      3,794.56000        NaN               NaN              3.00000
# 1      4,384.04000        NaN               NaN              2.00000
# 2      1,129.18000        NaN               NaN              1.00000
# 3      2,511.57000        NaN               NaN              5.00000
# 4      8,969.90000        NaN               NaN              1.00000
#
#   no_of_parties_role_2  no_of_parties_role_3
# 0              1.00000               0.00000
# 1              4.00000               0.00000
# 2              1.00000               0.00000
# 3              1.00000               0.00000
# 4              1.00000               0.00000
#
# [5 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1665112 entries, 0 to 1665111
# Data columns (total 46 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   transaction_id        1665112 non-null  str
#  1   procedure_id          1665112 non-null  int64
#  2   trans_group_id        1665112 non-null  int64
#  3   trans_group_ar        1665112 non-null  str
#  4   trans_group_en        1665112 non-null  str
#  5   procedure_name_ar     1665112 non-null  str
#  6   procedure_name_en     1665112 non-null  str
#  7   instance_date         1665112 non-null  str
#  8   property_type_id      1665112 non-null  int64
#  9   property_type_ar      1665112 non-null  str
#  10  property_type_en      1665112 non-null  str
#  11  property_sub_type_id  1330409 non-null  float64
#  12  property_sub_type_ar  1330409 non-null  str
#  13  property_sub_type_en  1330409 non-null  str
#  14  property_usage_ar     1665112 non-null  str
#  15  property_usage_en     1665112 non-null  str
#  16  reg_type_id           1665112 non-null  int64
#  17  reg_type_ar           1665112 non-null  str
#  18  reg_type_en           1665112 non-null  str
#  19  area_id               1665112 non-null  int64
#  20  area_name_ar          1665112 non-null  str
#  21  area_name_en          1665112 non-null  str
#  22  building_name_ar      1184463 non-null  str
#  23  building_name_en      1184919 non-null  str
#  24  project_number        1208450 non-null  float64
#  25  project_name_ar       1208450 non-null  str
#  26  project_name_en       1208450 non-null  str
#  27  master_project_en     1438955 non-null  str
#  28  master_project_ar     1438916 non-null  str
#  29  nearest_landmark_ar   1343474 non-null  str
#  30  nearest_landmark_en   1343474 non-null  str
#  31  nearest_metro_ar      1162079 non-null  str
#  32  nearest_metro_en      1162079 non-null  str
#  33  nearest_mall_ar       1152266 non-null  str
#  34  nearest_mall_en       1152266 non-null  str
#  35  rooms_ar              1306704 non-null  str
#  36  rooms_en              1306704 non-null  str
#  37  has_parking           1665112 non-null  int64
#  38  procedure_area        1665112 non-null  float64
#  39  actual_worth          1665112 non-null  float64
#  40  meter_sale_price      1665112 non-null  float64
#  41  rent_value            36551 non-null    float64
#  42  meter_rent_price      36551 non-null    float64
#  43  no_of_parties_role_1  1664143 non-null  float64
#  44  no_of_parties_role_2  1664143 non-null  float64
#  45  no_of_parties_role_3  1664143 non-null  float64
# dtypes: float64(10), int64(6), str(30)
# memory usage: 584.4 MB

# %%
df['procedure_name_en'].unique()
# Out:
# <StringArray>
# [                                           'Grant',
#                             'Mortgage Registration',
#                                              'Sell',
#                               'Adding Land By Sell',
#                                   'Modify Mortgage',
#                               'Lease to Own Modify',
#                                 'Mortgage Transfer',
#                         'Lease to Own Registration',
#                          'Development Registration',
#                                      'Delayed Sell',
#                           'Sell - Pre registration',
#                         'Mortgage Pre-Registration',
#                        'Lease Finance Registration',
#                   'Portfolio Mortgage Registration',
#                                  'Delayed Mortgage',
#        'Lease to Own Registration Pre-Registration',
#                             'Lease to Own Transfer',
#                 'Delayed Lease to Own Registration',
#                            'Grant Pre-Registration',
#                              'Sale On Payment Plan',
#                   'Portfolio Mortgage Modification',
#                                  'Sell Development',
#  'Portfolio Mortgage Registration Pre-Registration',
#                              'Development Mortgage',
#                                 'Grant Development',
#                    'Lease Development Registration',
#                             'Grant on Delayed Sell',
#                        'Lease Finance Modification',
#            'Delayed Sell Lease to Own Registration',
#         'Development Registration Pre-Registration',
#                       'Modify Development Mortgage',
#                               'Delayed Development',
#          'Lease to Own on Development Registration',
#                          'Modify Delayed Mortgage ',
#                          'Delayed Sell Development',
#       'Portfolio Mortgage Development Registration',
#                'Mortgage Transfer Pre-Registration',
#               'Sell Development - Pre Registration',
#  'Portfolio Mortgage Modification Pre-Registration',
#             'Development Mortgage Pre-Registration',
#            'Delayed Sell Lease To Own Modification',
#          'Lease to Own on Development Modification',
#                  'Modify Mortgage Pre-Registration',
#                'Portfolio Development Registration',
#       'Portfolio Mortgage Development Modification',
#                        'Delayed Portfolio Mortgage',
#                       'Portfolio Mortgage Transfer',
#                          'Lease Development Modify',
#            'Lease to Own Transfer Pre-Registration',
#                     'Transfer Development Mortgage',
#                       'Delayed Lease to Own Modify',
#                     'Delayed Lease to Own Transfer']
# Length: 52, dtype: str

# %% [markdown]
# # Data Pre-Processing

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1665112 entries, 0 to 1665111
# Data columns (total 46 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   transaction_id        1665112 non-null  str
#  1   procedure_id          1665112 non-null  int64
#  2   trans_group_id        1665112 non-null  int64
#  3   trans_group_ar        1665112 non-null  str
#  4   trans_group_en        1665112 non-null  str
#  5   procedure_name_ar     1665112 non-null  str
#  6   procedure_name_en     1665112 non-null  str
#  7   instance_date         1665112 non-null  str
#  8   property_type_id      1665112 non-null  int64
#  9   property_type_ar      1665112 non-null  str
#  10  property_type_en      1665112 non-null  str
#  11  property_sub_type_id  1330409 non-null  float64
#  12  property_sub_type_ar  1330409 non-null  str
#  13  property_sub_type_en  1330409 non-null  str
#  14  property_usage_ar     1665112 non-null  str
#  15  property_usage_en     1665112 non-null  str
#  16  reg_type_id           1665112 non-null  int64
#  17  reg_type_ar           1665112 non-null  str
#  18  reg_type_en           1665112 non-null  str
#  19  area_id               1665112 non-null  int64
#  20  area_name_ar          1665112 non-null  str
#  21  area_name_en          1665112 non-null  str
#  22  building_name_ar      1184463 non-null  str
#  23  building_name_en      1184919 non-null  str
#  24  project_number        1208450 non-null  float64
#  25  project_name_ar       1208450 non-null  str
#  26  project_name_en       1208450 non-null  str
#  27  master_project_en     1438955 non-null  str
#  28  master_project_ar     1438916 non-null  str
#  29  nearest_landmark_ar   1343474 non-null  str
#  30  nearest_landmark_en   1343474 non-null  str
#  31  nearest_metro_ar      1162079 non-null  str
#  32  nearest_metro_en      1162079 non-null  str
#  33  nearest_mall_ar       1152266 non-null  str
#  34  nearest_mall_en       1152266 non-null  str
#  35  rooms_ar              1306704 non-null  str
#  36  rooms_en              1306704 non-null  str
#  37  has_parking           1665112 non-null  int64
#  38  procedure_area        1665112 non-null  float64
#  39  actual_worth          1665112 non-null  float64
#  40  meter_sale_price      1665112 non-null  float64
#  41  rent_value            36551 non-null    float64
#  42  meter_rent_price      36551 non-null    float64
#  43  no_of_parties_role_1  1664143 non-null  float64
#  44  no_of_parties_role_2  1664143 non-null  float64
#  45  no_of_parties_role_3  1664143 non-null  float64
# dtypes: float64(10), int64(6), str(30)
# memory usage: 584.4 MB

# %% [markdown]
# ## 14,75,500 samples & 46 features

# %%
df['parsed_date'] = pd.to_datetime(df['instance_date'], format='%d-%m-%Y')

# %%
df['property_sub_type_en'].unique()
# Out:
# <StringArray>
# [                 nan,             'Office',               'Flat',
#                'Shop',              'Store',              'Villa',
#     'Hotel Apartment',        'Hotel Rooms',              'Hotel',
#              'Clinic',           'Building',          'Warehouse',
#  'Stacked Townhouses',           'Workshop',    'Sized Partition',
#          'Show Rooms',          'Gymnasium',               'Unit',
#             'Parking']
# Length: 19, dtype: str

# %%
print("\n\nLast 10 Entries \n\n")
print(df.sort_values(by='parsed_date').tail(10))
print("\n\n-----------------")
print("\n\nFirst 10 Entries \n\n")
print(df.sort_values(by='parsed_date').head(10))
# Out:
# Last 10 Entries
#
#
#            transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 1202936    1-11-2026-7315            11               1        مبايعات
# 202712   1-102-2026-17220           102               1        مبايعات
# 787567     1-41-2026-3020            41               1        مبايعات
# 834752     1-11-2026-7071            11               1        مبايعات
# 1359767  1-102-2026-17349           102               1        مبايعات
# 1127727  1-102-2026-17438           102               1        مبايعات
# 523002   1-102-2026-17187           102               1        مبايعات
# 299852   1-102-2026-17611           102               1        مبايعات
# 840667      2-14-2026-218            14               2           رهون
# 539343   1-102-2026-17140           102               1        مبايعات
#
#         trans_group_en  procedure_name_ar        procedure_name_en  \
# 1202936          Sales                بيع                     Sell
# 202712           Sales  بيع - تسجيل مبدئى  Sell - Pre registration
# 787567           Sales          بيع مبدئى             Delayed Sell
# 834752           Sales                بيع                     Sell
# 1359767          Sales  بيع - تسجيل مبدئى  Sell - Pre registration
# 1127727          Sales  بيع - تسجيل مبدئى  Sell - Pre registration
# 523002           Sales  بيع - تسجيل مبدئى  Sell - Pre registration
# 299852           Sales  بيع - تسجيل مبدئى  Sell - Pre registration
# 840667       Mortgages          تعديل رهن          Modify Mortgage
# 539343           Sales  بيع - تسجيل مبدئى  Sell - Pre registration
#
#         instance_date  property_type_id property_type_ar  ... has_parking  \
# 1202936    17-02-2026                 3             وحدة  ...           1
# 202712     17-02-2026                 3             وحدة  ...           1
# 787567     17-02-2026                 3             وحدة  ...           1
# 834752     17-02-2026                 3             وحدة  ...           0
# 1359767    17-02-2026                 3             وحدة  ...           1
# 1127727    17-02-2026                 3             وحدة  ...           1
# 523002     17-02-2026                 3             وحدة  ...           1
# 299852     17-02-2026                 4             فيلا  ...           0
# 840667     17-02-2026                 3             وحدة  ...           1
# 539343     17-02-2026                 4             فيلا  ...           0
#
#          procedure_area    actual_worth meter_sale_price rent_value  \
# 1202936        83.02000 1,680,000.00000     20,236.09000        NaN
# 202712         62.25000 2,824,000.00000     45,365.46000        NaN
# 787567         88.04000 2,021,000.00000     22,955.47000        NaN
# 834752         45.00000   380,000.00000      8,444.44000        NaN
# 1359767        68.69000 2,180,000.00000     31,736.79000        NaN
# 1127727        37.28000   475,000.00000     12,741.42000        NaN
# 523002        102.35000 1,605,985.00000     15,691.11000        NaN
# 299852        224.91000 5,008,000.00000     22,266.68000        NaN
# 840667        101.56000 1,680,000.00000     16,541.95000        NaN
# 539343        191.93000 3,260,000.00000     16,985.36000        NaN
#
#         meter_rent_price  no_of_parties_role_1 no_of_parties_role_2  \
# 1202936              NaN               1.00000              1.00000
# 202712               NaN               1.00000              1.00000
# 787567               NaN               1.00000              1.00000
# 834752               NaN               1.00000              1.00000
# 1359767              NaN               1.00000              1.00000
# 1127727              NaN               1.00000              1.00000
# 523002               NaN               1.00000              1.00000
# 299852               NaN               1.00000              1.00000
# 840667               NaN               1.00000              1.00000
# 539343               NaN               1.00000              2.00000
#
#         no_of_parties_role_3  parsed_date
# 1202936              0.00000   2026-02-17
# 202712               0.00000   2026-02-17
# 787567               0.00000   2026-02-17
# 834752               0.00000   2026-02-17
# 1359767              0.00000   2026-02-17
# 1127727              0.00000   2026-02-17
# 523002               0.00000   2026-02-17
# 299852               0.00000   2026-02-17
# 840667               0.00000   2026-02-17
# 539343               0.00000   2026-02-17
#
# [10 rows x 47 columns]
#
#
# -----------------
#
#
# First 10 Entries
#
#
#         transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 907854   2-13-1995-128            13               2           رهون
# 388923   2-13-1996-190            13               2           رهون
# 388766   2-13-1999-631            13               2           رهون
# 45381    2-13-1995-137            13               2           رهون
# 1492125  2-13-1996-201            13               2           رهون
# 269797     2-13-1967-1            13               2           رهون
# 1326142    1-11-1975-2            11               1        مبايعات
# 1455583    2-13-1975-1            13               2           رهون
# 1207374    2-13-1975-2            13               2           رهون
# 556130     2-13-1976-7            13               2           رهون
#
#         trans_group_en procedure_name_ar      procedure_name_en instance_date  \
# 907854       Mortgages         تسجيل رهن  Mortgage Registration    02-07-1416
# 388923       Mortgages         تسجيل رهن  Mortgage Registration    04-02-1417
# 388766       Mortgages         تسجيل رهن  Mortgage Registration    30-01-1420
# 45381        Mortgages         تسجيل رهن  Mortgage Registration    23-11-1422
# 1492125      Mortgages         تسجيل رهن  Mortgage Registration    18-01-1966
# 269797       Mortgages         تسجيل رهن  Mortgage Registration    28-11-1967
# 1326142          Sales               بيع                   Sell    01-01-1975
# 1455583      Mortgages         تسجيل رهن  Mortgage Registration    23-06-1975
# 1207374      Mortgages         تسجيل رهن  Mortgage Registration    28-07-1975
# 556130       Mortgages         تسجيل رهن  Mortgage Registration    05-11-1975
#
#          property_type_id property_type_ar  ... has_parking  procedure_area  \
# 907854                  4             فيلا  ...           0     1,858.06000
# 388923                  2             مبنى  ...           0       305.84000
# 388766                  4             فيلا  ...           0     2,092.92000
# 45381                   2             مبنى  ...           0       378.95000
# 1492125                 1              أرض  ...           0     1,858.06000
# 269797                  1              أرض  ...           0        42.92000
# 1326142                 4             فيلا  ...           0       692.31000
# 1455583                 1              أرض  ...           0       389.77000
# 1207374                 1              أرض  ...           0       136.29000
# 556130                  1              أرض  ...           0       598.95000
#
#            actual_worth meter_sale_price rent_value meter_rent_price  \
# 907854    500,000.00000        269.10000        NaN              NaN
# 388923  2,290,000.00000      7,487.58000        NaN              NaN
# 388766    500,000.00000        238.90000        NaN              NaN
# 45381   2,000,000.00000      5,277.74000        NaN              NaN
# 1492125   755,327.00000        406.51000        NaN              NaN
# 269797     39,750.00000        926.14000        NaN              NaN
# 1326142    50,000.00000         72.22000        NaN              NaN
# 1455583   750,000.00000      1,924.21000        NaN              NaN
# 1207374 3,000,000.00000     22,011.89000        NaN              NaN
# 556130  1,800,000.00000      3,005.26000        NaN              NaN
#
#          no_of_parties_role_1 no_of_parties_role_2 no_of_parties_role_3  \
# 907854                1.00000              1.00000              0.00000
# 388923                1.00000              1.00000              0.00000
# 388766                1.00000              1.00000              0.00000
# 45381                 1.00000              1.00000              0.00000
# 1492125               1.00000              1.00000              0.00000
# 269797                1.00000              1.00000              0.00000
# 1326142               1.00000              1.00000              0.00000
# 1455583               2.00000              1.00000              0.00000
# 1207374               1.00000              1.00000              0.00000
# 556130                1.00000              1.00000              0.00000
#
#          parsed_date
# 907854    1416-07-02
# 388923    1417-02-04
# 388766    1420-01-30
# 45381     1422-11-23
# 1492125   1966-01-18
# 269797    1967-11-28
# 1326142   1975-01-01
# 1455583   1975-06-23
# 1207374   1975-07-28
# 556130    1975-11-05
#
# [10 rows x 47 columns]

# %%
# the first four transactions are from 1416 to 1422 which seems weird and can be removed. They will skew the data unnecessarily

# %% [markdown]
# ### We have transaction data from 18th January, 1966 to 12th June, 2025

# %%
df[df['parsed_date'].isna()]
# Out:
# Empty DataFrame
# Columns: [transaction_id, procedure_id, trans_group_id, trans_group_ar, trans_group_en, procedure_name_ar, procedure_name_en, instance_date, property_type_id, property_type_ar, property_type_en, property_sub_type_id, property_sub_type_ar, property_sub_type_en, property_usage_ar, property_usage_en, reg_type_id, reg_type_ar, reg_type_en, area_id, area_name_ar, area_name_en, building_name_ar, building_name_en, project_number, project_name_ar, project_name_en, master_project_en, master_project_ar, nearest_landmark_ar, nearest_landmark_en, nearest_metro_ar, nearest_metro_en, nearest_mall_ar, nearest_mall_en, rooms_ar, rooms_en, has_parking, procedure_area, actual_worth, meter_sale_price, rent_value, meter_rent_price, no_of_parties_role_1, no_of_parties_role_2, no_of_parties_role_3, parsed_date]
# Index: []
#
# [0 rows x 47 columns]

# %%
df1 = df[4:].reset_index(drop=True)

# %%
print(f"Total transactions earlier: {len(df)}")
print(f"Total transactions now: {len(df1)}")
# Out:
# Total transactions earlier: 1665112
# Total transactions now: 1665108

# %%
print(f"Earliest transaction earlier was {df.loc[0, 'parsed_date']}")
print(f"Earliest transaction now is {df1.loc[0, 'parsed_date']}")
# Out:
# Earliest transaction earlier was 2006-10-16 00:00:00
# Earliest transaction now is 2020-11-30 00:00:00

# %% [markdown]
# ## Now we are left with 14,75,496 transactions

# %%
df1.head()
# Out:
#     transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 0   2-13-2020-9477            13               2           رهون
# 1      3-9-2002-70             9               3           هبات
# 2  1-11-2013-15239            11               1        مبايعات
# 3      1-4-2012-13             4               1        مبايعات
# 4    2-13-1999-532            13               2           رهون
#
#   trans_group_en procedure_name_ar      procedure_name_en instance_date  \
# 0      Mortgages         تسجيل رهن  Mortgage Registration    30-11-2020
# 1          Gifts               هبه                  Grant    29-05-2002
# 2          Sales               بيع                   Sell    16-05-2013
# 3          Sales  إضافة أرض بالبيع    Adding Land By Sell    19-04-2012
# 4      Mortgages         تسجيل رهن  Mortgage Registration    26-04-1999
#
#    property_type_id property_type_ar  ... has_parking  procedure_area  \
# 0                 2             مبنى  ...           0       278.71000
# 1                 4             فيلا  ...           0       276.39000
# 2                 4             فيلا  ...           0       382.67000
# 3                 2             مبنى  ...           0       346.81000
# 4                 4             فيلا  ...           0     3,626.93000
#
#      actual_worth meter_sale_price rent_value meter_rent_price  \
# 0 2,500,000.00000      8,969.90000        NaN              NaN
# 1   500,000.00000      1,809.04000        NaN              NaN
# 2 2,000,000.00000      5,226.44000        NaN              NaN
# 3   920,700.00000      2,654.77000        NaN              NaN
# 4 1,900,000.00000        523.86000        NaN              NaN
#
#    no_of_parties_role_1 no_of_parties_role_2 no_of_parties_role_3  parsed_date
# 0               1.00000              1.00000              0.00000   2020-11-30
# 1               1.00000              1.00000              0.00000   2002-05-29
# 2               1.00000              1.00000              0.00000   2013-05-16
# 3               1.00000              1.00000              0.00000   2012-04-19
# 4               1.00000              1.00000              0.00000   1999-04-26
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Dropping Non-Informative Arabic Columns

# %%
ar_columns = [column for column in df1.columns.to_list() if column.endswith('_ar')]
ar_columns
# Out:
# ['trans_group_ar',
#  'procedure_name_ar',
#  'property_type_ar',
#  'property_sub_type_ar',
#  'property_usage_ar',
#  'reg_type_ar',
#  'area_name_ar',
#  'building_name_ar',
#  'project_name_ar',
#  'master_project_ar',
#  'nearest_landmark_ar',
#  'nearest_metro_ar',
#  'nearest_mall_ar',
#  'rooms_ar']

# %%
df2 = df1.drop(columns=ar_columns)

# %%
df2.columns
# Out:
# Index(['transaction_id', 'procedure_id', 'trans_group_id', 'trans_group_en',
#        'procedure_name_en', 'instance_date', 'property_type_id',
#        'property_type_en', 'property_sub_type_id', 'property_sub_type_en',
#        'property_usage_en', 'reg_type_id', 'reg_type_en', 'area_id',
#        'area_name_en', 'building_name_en', 'project_number', 'project_name_en',
#        'master_project_en', 'nearest_landmark_en', 'nearest_metro_en',
#        'nearest_mall_en', 'rooms_en', 'has_parking', 'procedure_area',
#        'actual_worth', 'meter_sale_price', 'rent_value', 'meter_rent_price',
#        'no_of_parties_role_1', 'no_of_parties_role_2', 'no_of_parties_role_3',
#        'parsed_date'],
#       dtype='str')

# %%
df2.property_usage_en.unique()
# Out:
# <StringArray>
# [                          'Residential',
#                             'Commercial',
#                             'Industrial',
#               'Residential / Commercial',
#                                  'Other',
#                              'Multi-Use',
#                                'Storage',
#                           'Agricultural',
#                           'Hospitality ',
#                'Industrial / Commercial',
#  'Industrial / Commercial / Residential']
# Length: 11, dtype: str

# %% [markdown]
# ## Filtering observations by Property Classifications
#
# `property_usage_en` column
#
# We need to make a decision to use which all properties from `property_usage_en`.
# eg: If we want to just use Residential properties, then we need to filter out the usage types of following:
# 1. Residential
# 2. Residential / Commercial
# 3. Industrial / Commercial / Residential
# 4. Multi-Use
#
# _Multi-Use might be removed seeing it's values_

# %%
allowed_usages = ['Residential', 'Residential / Commercial', 'Industrial / Commercial / Residential', 'Multi-Use']
res_df = df2[df2['property_usage_en'].isin(allowed_usages)]

# %%
res_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1406101 entries, 0 to 1665107
# Data columns (total 33 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   transaction_id        1406101 non-null  str
#  1   procedure_id          1406101 non-null  int64
#  2   trans_group_id        1406101 non-null  int64
#  3   trans_group_en        1406101 non-null  str
#  4   procedure_name_en     1406101 non-null  str
#  5   instance_date         1406101 non-null  str
#  6   property_type_id      1406101 non-null  int64
#  7   property_type_en      1406101 non-null  str
#  8   property_sub_type_id  1200852 non-null  float64
#  9   property_sub_type_en  1200852 non-null  str
#  10  property_usage_en     1406101 non-null  str
#  11  reg_type_id           1406101 non-null  int64
#  12  reg_type_en           1406101 non-null  str
#  13  area_id               1406101 non-null  int64
#  14  area_name_en          1406101 non-null  str
#  15  building_name_en      1055514 non-null  str
#  16  project_number        1047071 non-null  float64
#  17  project_name_en       1047071 non-null  str
#  18  master_project_en     1223019 non-null  str
#  19  nearest_landmark_en   1127130 non-null  str
#  20  nearest_metro_en      954627 non-null   str
#  21  nearest_mall_en       946764 non-null   str
#  22  rooms_en              1200232 non-null  str
#  23  has_parking           1406101 non-null  int64
#  24  procedure_area        1406101 non-null  float64
#  25  actual_worth          1406101 non-null  float64
#  26  meter_sale_price      1406101 non-null  float64
#  27  rent_value            31330 non-null    float64
#  28  meter_rent_price      31330 non-null    float64
#  29  no_of_parties_role_1  1405385 non-null  float64
#  30  no_of_parties_role_2  1405385 non-null  float64
#  31  no_of_parties_role_3  1405385 non-null  float64
#  32  parsed_date           1406101 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(10), int64(6), str(16)
# memory usage: 364.7 MB

# %% [markdown]
# ## 14,75,499 samples & 33 features

# %% [markdown]
# Property Type Evaluation

# %%
res_df.property_type_en.unique()
# Out:
# <StringArray>
# ['Building', 'Villa', 'Land', 'Unit']
# Length: 4, dtype: str

# %% [markdown]
# We have 'Villa', 'Building', 'Land', 'Unit' types of properties

# %%
# For this model, let's focus on "Unit" type

res_units = res_df[res_df['property_type_en'] == 'Unit']
res_units2 = res_units.drop(columns=['property_type_en', 'property_type_id'])
res_units2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1055514 entries, 370 to 1665107
# Data columns (total 31 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   transaction_id        1055514 non-null  str
#  1   procedure_id          1055514 non-null  int64
#  2   trans_group_id        1055514 non-null  int64
#  3   trans_group_en        1055514 non-null  str
#  4   procedure_name_en     1055514 non-null  str
#  5   instance_date         1055514 non-null  str
#  6   property_sub_type_id  1055514 non-null  float64
#  7   property_sub_type_en  1055514 non-null  str
#  8   property_usage_en     1055514 non-null  str
#  9   reg_type_id           1055514 non-null  int64
#  10  reg_type_en           1055514 non-null  str
#  11  area_id               1055514 non-null  int64
#  12  area_name_en          1055514 non-null  str
#  13  building_name_en      1055514 non-null  str
#  14  project_number        832200 non-null   float64
#  15  project_name_en       832200 non-null   str
#  16  master_project_en     997856 non-null   str
#  17  nearest_landmark_en   895170 non-null   str
#  18  nearest_metro_en      811544 non-null   str
#  19  nearest_mall_en       807433 non-null   str
#  20  rooms_en              1055251 non-null  str
#  21  has_parking           1055514 non-null  int64
#  22  procedure_area        1055514 non-null  float64
#  23  actual_worth          1055514 non-null  float64
#  24  meter_sale_price      1055514 non-null  float64
#  25  rent_value            23422 non-null    float64
#  26  meter_rent_price      23422 non-null    float64
#  27  no_of_parties_role_1  1054800 non-null  float64
#  28  no_of_parties_role_2  1054800 non-null  float64
#  29  no_of_parties_role_3  1054800 non-null  float64
#  30  parsed_date           1055514 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(10), int64(5), str(15)
# memory usage: 257.7 MB

# %% [markdown]
# ## Property Subtype

# %%
res_units2.property_sub_type_en.unique()
# Out:
# <StringArray>
# ['Flat', 'Stacked Townhouses', 'Unit']
# Length: 3, dtype: str

# %% [markdown]
# We have 3 types of sub types now:
#
# 1. Flat
# 2. Stacked Townhouses
# 3. Unit

# %%
sns.countplot(data=res_units2, x='property_sub_type_en', legend='auto', stat='count', palette='pastel', hue='property_sub_type_en')
plt.title('Property Subtype Count')
plt.show()

# %%
res_units2.property_sub_type_en.value_counts()
# Out:
# property_sub_type_en
# Flat                  1054990
# Stacked Townhouses        522
# Unit                        2
# Name: count, dtype: int64

# %% [markdown]
# Since we don't want Stacked Townhouses for now and the unit is only 1 in count. It's better to just filter out the flats.

# %%
flats_df = res_units2[res_units2['property_sub_type_en'] == 'Flat']
flats_df2 = flats_df.drop(columns=['property_sub_type_en', 'property_sub_type_id'])
flats_df2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1054990 entries, 370 to 1665107
# Data columns (total 29 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   transaction_id        1054990 non-null  str
#  1   procedure_id          1054990 non-null  int64
#  2   trans_group_id        1054990 non-null  int64
#  3   trans_group_en        1054990 non-null  str
#  4   procedure_name_en     1054990 non-null  str
#  5   instance_date         1054990 non-null  str
#  6   property_usage_en     1054990 non-null  str
#  7   reg_type_id           1054990 non-null  int64
#  8   reg_type_en           1054990 non-null  str
#  9   area_id               1054990 non-null  int64
#  10  area_name_en          1054990 non-null  str
#  11  building_name_en      1054990 non-null  str
#  12  project_number        831676 non-null   float64
#  13  project_name_en       831676 non-null   str
#  14  master_project_en     997332 non-null   str
#  15  nearest_landmark_en   894646 non-null   str
#  16  nearest_metro_en      811543 non-null   str
#  17  nearest_mall_en       807432 non-null   str
#  18  rooms_en              1054727 non-null  str
#  19  has_parking           1054990 non-null  int64
#  20  procedure_area        1054990 non-null  float64
#  21  actual_worth          1054990 non-null  float64
#  22  meter_sale_price      1054990 non-null  float64
#  23  rent_value            23416 non-null    float64
#  24  meter_rent_price      23416 non-null    float64
#  25  no_of_parties_role_1  1054276 non-null  float64
#  26  no_of_parties_role_2  1054276 non-null  float64
#  27  no_of_parties_role_3  1054276 non-null  float64
#  28  parsed_date           1054990 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(9), int64(5), str(14)
# memory usage: 241.5 MB

# %% [markdown]
# ## 9,11,523 Samples and 29 Features

# %% [markdown]
# We can remove _instance_date_, since we already have _parsed_date_

# %%
flats_df3 = flats_df2.drop(columns=['instance_date'])
flats_df3.shape
# Out:
# (1054990, 28)

# %% [markdown]
# ## 9,11,523 Samples and 28 Features

# %%
flats_df3.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1054990 entries, 370 to 1665107
# Data columns (total 28 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   transaction_id        1054990 non-null  str
#  1   procedure_id          1054990 non-null  int64
#  2   trans_group_id        1054990 non-null  int64
#  3   trans_group_en        1054990 non-null  str
#  4   procedure_name_en     1054990 non-null  str
#  5   property_usage_en     1054990 non-null  str
#  6   reg_type_id           1054990 non-null  int64
#  7   reg_type_en           1054990 non-null  str
#  8   area_id               1054990 non-null  int64
#  9   area_name_en          1054990 non-null  str
#  10  building_name_en      1054990 non-null  str
#  11  project_number        831676 non-null   float64
#  12  project_name_en       831676 non-null   str
#  13  master_project_en     997332 non-null   str
#  14  nearest_landmark_en   894646 non-null   str
#  15  nearest_metro_en      811543 non-null   str
#  16  nearest_mall_en       807432 non-null   str
#  17  rooms_en              1054727 non-null  str
#  18  has_parking           1054990 non-null  int64
#  19  procedure_area        1054990 non-null  float64
#  20  actual_worth          1054990 non-null  float64
#  21  meter_sale_price      1054990 non-null  float64
#  22  rent_value            23416 non-null    float64
#  23  meter_rent_price      23416 non-null    float64
#  24  no_of_parties_role_1  1054276 non-null  float64
#  25  no_of_parties_role_2  1054276 non-null  float64
#  26  no_of_parties_role_3  1054276 non-null  float64
#  27  parsed_date           1054990 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(9), int64(5), str(13)
# memory usage: 233.4 MB

# %%
flats_df3.property_usage_en.value_counts()
# Out:
# property_usage_en
# Residential    1054990
# Name: count, dtype: int64

# %% [markdown]
# ## Property Usage
#
# Only 1 value type now exists, we can remove it.

# %%
flats_df4 = flats_df3.drop(columns=['property_usage_en'])
flats_df4.shape
# Out:
# (1054990, 27)

# %%
flats_df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1054990 entries, 370 to 1665107
# Data columns (total 27 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   transaction_id        1054990 non-null  str
#  1   procedure_id          1054990 non-null  int64
#  2   trans_group_id        1054990 non-null  int64
#  3   trans_group_en        1054990 non-null  str
#  4   procedure_name_en     1054990 non-null  str
#  5   reg_type_id           1054990 non-null  int64
#  6   reg_type_en           1054990 non-null  str
#  7   area_id               1054990 non-null  int64
#  8   area_name_en          1054990 non-null  str
#  9   building_name_en      1054990 non-null  str
#  10  project_number        831676 non-null   float64
#  11  project_name_en       831676 non-null   str
#  12  master_project_en     997332 non-null   str
#  13  nearest_landmark_en   894646 non-null   str
#  14  nearest_metro_en      811543 non-null   str
#  15  nearest_mall_en       807432 non-null   str
#  16  rooms_en              1054727 non-null  str
#  17  has_parking           1054990 non-null  int64
#  18  procedure_area        1054990 non-null  float64
#  19  actual_worth          1054990 non-null  float64
#  20  meter_sale_price      1054990 non-null  float64
#  21  rent_value            23416 non-null    float64
#  22  meter_rent_price      23416 non-null    float64
#  23  no_of_parties_role_1  1054276 non-null  float64
#  24  no_of_parties_role_2  1054276 non-null  float64
#  25  no_of_parties_role_3  1054276 non-null  float64
#  26  parsed_date           1054990 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(9), int64(5), str(12)
# memory usage: 225.4 MB

# %% [markdown]
# ## 9,11,523 Samples & 27 Features

# %% [markdown]
# ## Registration type

# %% [markdown]
# ## 12,61,949 samples & 33 features left

# %% [markdown]
# ## Dropping Non-Informative Identifier Columns

# %%
flats_df4.columns
# Out:
# Index(['transaction_id', 'procedure_id', 'trans_group_id', 'trans_group_en',
#        'procedure_name_en', 'reg_type_id', 'reg_type_en', 'area_id',
#        'area_name_en', 'building_name_en', 'project_number', 'project_name_en',
#        'master_project_en', 'nearest_landmark_en', 'nearest_metro_en',
#        'nearest_mall_en', 'rooms_en', 'has_parking', 'procedure_area',
#        'actual_worth', 'meter_sale_price', 'rent_value', 'meter_rent_price',
#        'no_of_parties_role_1', 'no_of_parties_role_2', 'no_of_parties_role_3',
#        'parsed_date'],
#       dtype='str')

# %%
flats_df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1054990 entries, 370 to 1665107
# Data columns (total 27 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   transaction_id        1054990 non-null  str
#  1   procedure_id          1054990 non-null  int64
#  2   trans_group_id        1054990 non-null  int64
#  3   trans_group_en        1054990 non-null  str
#  4   procedure_name_en     1054990 non-null  str
#  5   reg_type_id           1054990 non-null  int64
#  6   reg_type_en           1054990 non-null  str
#  7   area_id               1054990 non-null  int64
#  8   area_name_en          1054990 non-null  str
#  9   building_name_en      1054990 non-null  str
#  10  project_number        831676 non-null   float64
#  11  project_name_en       831676 non-null   str
#  12  master_project_en     997332 non-null   str
#  13  nearest_landmark_en   894646 non-null   str
#  14  nearest_metro_en      811543 non-null   str
#  15  nearest_mall_en       807432 non-null   str
#  16  rooms_en              1054727 non-null  str
#  17  has_parking           1054990 non-null  int64
#  18  procedure_area        1054990 non-null  float64
#  19  actual_worth          1054990 non-null  float64
#  20  meter_sale_price      1054990 non-null  float64
#  21  rent_value            23416 non-null    float64
#  22  meter_rent_price      23416 non-null    float64
#  23  no_of_parties_role_1  1054276 non-null  float64
#  24  no_of_parties_role_2  1054276 non-null  float64
#  25  no_of_parties_role_3  1054276 non-null  float64
#  26  parsed_date           1054990 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(9), int64(5), str(12)
# memory usage: 225.4 MB

# %%
for column in flats_df4.columns.to_list():
    print(f"Unique value count for {column}: {res_df[column].nunique()}")
# Out:
# Unique value count for transaction_id: 1406101
# Unique value count for procedure_id: 49
# Unique value count for trans_group_id: 3
# Unique value count for trans_group_en: 3
# Unique value count for procedure_name_en: 49
# Unique value count for reg_type_id: 2
# Unique value count for reg_type_en: 2
# Unique value count for area_id: 216
# Unique value count for area_name_en: 216
# Unique value count for building_name_en: 4446
# Unique value count for project_number: 2912
# Unique value count for project_name_en: 2908
# Unique value count for master_project_en: 159
# Unique value count for nearest_landmark_en: 14
# Unique value count for nearest_metro_en: 55
# Unique value count for nearest_mall_en: 5
# Unique value count for rooms_en: 15
# Unique value count for has_parking: 2
# Unique value count for procedure_area: 71074
# Unique value count for actual_worth: 302489
# Unique value count for meter_sale_price: 799228
# Unique value count for rent_value: 13090
# Unique value count for meter_rent_price: 25659
# Unique value count for no_of_parties_role_1: 141
# Unique value count for no_of_parties_role_2: 27
# Unique value count for no_of_parties_role_3: 10
# Unique value count for parsed_date: 6242

# %%
## Dropping transaction_id column
flats_df5 = flats_df4.drop(columns=['transaction_id'])

# %%
flats_df5.head()
# Out:
#      procedure_id  trans_group_id trans_group_en          procedure_name_en  \
# 370            11               1          Sales                       Sell
# 371           110               1          Sales  Lease to Own Registration
# 372            11               1          Sales                       Sell
# 379           102               1          Sales    Sell - Pre registration
# 380           102               1          Sales    Sell - Pre registration
#
#      reg_type_id          reg_type_en  area_id    area_name_en  \
# 370            1  Existing Properties      255  Rega Al Buteen
# 371            1  Existing Properties      255  Rega Al Buteen
# 372            1  Existing Properties      255  Rega Al Buteen
# 379            0  Off-Plan Properties      390    Burj Khalifa
# 380            0  Off-Plan Properties      390    Burj Khalifa
#
#     building_name_en  project_number  ... has_parking procedure_area  \
# 370    EMAAR TOWER 1             NaN  ...           1       85.75000
# 371    EMAAR TOWER 1             NaN  ...           1      316.71000
# 372    EMAAR TOWER 2             NaN  ...           1      161.37000
# 379      VOLTA TOWER     2,782.00000  ...           1      130.18000
# 380      VOLTA TOWER     2,782.00000  ...           1      130.06000
#
#        actual_worth meter_sale_price rent_value meter_rent_price  \
# 370 1,025,000.00000     11,953.35000        NaN              NaN
# 371 4,641,888.00000     14,656.59000        NaN              NaN
# 372 1,200,000.00000      7,436.33000        NaN              NaN
# 379 2,992,000.00000     22,983.56000        NaN              NaN
# 380 3,465,000.00000     26,641.55000        NaN              NaN
#
#      no_of_parties_role_1  no_of_parties_role_2  no_of_parties_role_3  \
# 370               1.00000               1.00000               0.00000
# 371               2.00000               2.00000               2.00000
# 372               1.00000               1.00000               0.00000
# 379               1.00000               2.00000               0.00000
# 380               1.00000               1.00000               0.00000
#
#      parsed_date
# 370   2016-02-15
# 371   2009-11-24
# 372   2018-05-01
# 379   2024-01-16
# 380   2024-05-07
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Evaluating `procedure_id` and `procedure_name_en`

# %%
flats_df5.columns
# Out:
# Index(['procedure_id', 'trans_group_id', 'trans_group_en', 'procedure_name_en',
#        'reg_type_id', 'reg_type_en', 'area_id', 'area_name_en',
#        'building_name_en', 'project_number', 'project_name_en',
#        'master_project_en', 'nearest_landmark_en', 'nearest_metro_en',
#        'nearest_mall_en', 'rooms_en', 'has_parking', 'procedure_area',
#        'actual_worth', 'meter_sale_price', 'rent_value', 'meter_rent_price',
#        'no_of_parties_role_1', 'no_of_parties_role_2', 'no_of_parties_role_3',
#        'parsed_date'],
#       dtype='str')

# %%
flats_df5.procedure_name_en.nunique()
# Out:
# 38

# %%
flats_df5.procedure_name_en.value_counts()
# Out:
# procedure_name_en
# Sell - Pre registration                       464877
# Sell                                          311336
# Mortgage Registration                         103423
# Delayed Sell                                   48057
# Lease to Own Registration                      37532
# Grant                                          27933
# Delayed Mortgage                                7935
# Sell Development                                7737
# Development Registration                        7345
# Lease to Own Registration Pre-Registration      6133
# Modify Mortgage                                 4991
# Lease Finance Registration                      4751
# Mortgage Pre-Registration                       4435
# Development Mortgage                            3702
# Development Registration Pre-Registration       3260
# Grant Pre-Registration                          2236
# Sale On Payment Plan                            1885
# Delayed Development                             1280
# Mortgage Transfer                               1186
# Lease Development Registration                   886
# Delayed Lease to Own Registration                854
# Grant on Delayed Sell                            811
# Grant Development                                632
# Lease to Own on Development Registration         452
# Modify Development Mortgage                      245
# Delayed Sell Lease to Own Registration           228
# Lease to Own Transfer                            226
# Delayed Sell Development                         160
# Sell Development - Pre Registration              148
# Lease to Own Modify                              144
# Lease Finance Modification                        95
# Mortgage Transfer Pre-Registration                37
# Modify Mortgage Pre-Registration                  18
# Development Mortgage Pre-Registration             12
# Modify Delayed Mortgage                            5
# Lease Development Modify                           1
# Delayed Lease to Own Modify                        1
# Lease to Own on Development Modification           1
# Name: count, dtype: int64

# %%
len(flats_df5)
# Out:
# 1054990

# %% [markdown]
# ## ❗ Need more information on transaction procedure
#
# Need to know which all types of transactions to use based on `procedure_name_en`

# %%
# Sell - Pre registration                       372812
# Sell                                          286038
# Mortgage Registration                          89645
# Delayed Sell                                   44974
# Lease to Own Registration                      36600
# Grant                                          24878
# Development Registration                        7094
# Sell Development                                6954
# Delayed Mortgage                                6608
# Lease to Own Registration Pre-Registration      6129
# Lease Finance Registration

most_likely_needed_procedures = ['Sell - Pre registration', 'Sell', 'Mortgage Registration', 
                                 'Delayed Sell', 'Lease to Own Registration', 'Grant',
                                 'Development Registration', 'Sell Development',
                                 'Delayed Mortgage', 'Lease to Own Registration Pre-Registration',
                                 'Lease Finance Registration']

# %%
likely_needed_transactions = len(flats_df5[flats_df5['procedure_name_en'].isin(most_likely_needed_procedures)])
total_transactions = len(flats_df5)

print(f"Likely needed transactions are {round(likely_needed_transactions/total_transactions * 100, 2)}% of total transactions")
# Out:
# Likely needed transactions are 97.35% of total transactions

# %%
flats_df6 = flats_df5[flats_df5['procedure_name_en'].isin(most_likely_needed_procedures)]

# %%
flats_df6.head()
# Out:
#      procedure_id  trans_group_id trans_group_en          procedure_name_en  \
# 370            11               1          Sales                       Sell
# 371           110               1          Sales  Lease to Own Registration
# 372            11               1          Sales                       Sell
# 379           102               1          Sales    Sell - Pre registration
# 380           102               1          Sales    Sell - Pre registration
#
#      reg_type_id          reg_type_en  area_id    area_name_en  \
# 370            1  Existing Properties      255  Rega Al Buteen
# 371            1  Existing Properties      255  Rega Al Buteen
# 372            1  Existing Properties      255  Rega Al Buteen
# 379            0  Off-Plan Properties      390    Burj Khalifa
# 380            0  Off-Plan Properties      390    Burj Khalifa
#
#     building_name_en  project_number  ... has_parking procedure_area  \
# 370    EMAAR TOWER 1             NaN  ...           1       85.75000
# 371    EMAAR TOWER 1             NaN  ...           1      316.71000
# 372    EMAAR TOWER 2             NaN  ...           1      161.37000
# 379      VOLTA TOWER     2,782.00000  ...           1      130.18000
# 380      VOLTA TOWER     2,782.00000  ...           1      130.06000
#
#        actual_worth meter_sale_price rent_value meter_rent_price  \
# 370 1,025,000.00000     11,953.35000        NaN              NaN
# 371 4,641,888.00000     14,656.59000        NaN              NaN
# 372 1,200,000.00000      7,436.33000        NaN              NaN
# 379 2,992,000.00000     22,983.56000        NaN              NaN
# 380 3,465,000.00000     26,641.55000        NaN              NaN
#
#      no_of_parties_role_1  no_of_parties_role_2  no_of_parties_role_3  \
# 370               1.00000               1.00000               0.00000
# 371               2.00000               2.00000               2.00000
# 372               1.00000               1.00000               0.00000
# 379               1.00000               2.00000               0.00000
# 380               1.00000               1.00000               0.00000
#
#      parsed_date
# 370   2016-02-15
# 371   2009-11-24
# 372   2018-05-01
# 379   2024-01-16
# 380   2024-05-07
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Transaction Group
#
# This has 2 columns:
# 1. trans_group_id (Identifier)
# 2. trans_group_en (Value)

# %%
flats_df6.trans_group_en.unique()
# Out:
# <StringArray>
# ['Sales', 'Mortgages', 'Gifts']
# Length: 3, dtype: str

# %%
flats_df6.trans_group_en.value_counts()
# Out:
# trans_group_en
# Sales        861184
# Mortgages    137942
# Gifts         27933
# Name: count, dtype: int64

# %%
fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=10,
    values=flats_df5.trans_group_en.value_counts(),
    legend={
        'labels': [f"{k} ({format_num(v)})" for k, v in flats_df6.trans_group_en.value_counts().items()],
        'loc': 'upper left',
        'bbox_to_anchor': (1.1, 1)
    }
)
fig.savefig('transaction_group_composition.png')
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
flats_df6[flats_df6.trans_group_en == 'Gifts'][['meter_sale_price', 'procedure_area', 'actual_worth']].head()
# Out:
#      meter_sale_price  procedure_area    actual_worth
# 586      15,069.46000        65.81000   991,721.00000
# 589      14,563.09000        77.51000 1,128,785.00000
# 651      16,145.84000       110.42000 1,782,824.00000
# 667      13,403.71000        85.71000 1,148,832.00000
# 672      18,779.85000       186.37000 3,500,000.00000

# %%
flats_df6[flats_df6.trans_group_en == 'Sales'][['meter_sale_price', 'procedure_area', 'actual_worth']].head()
# Out:
#      meter_sale_price  procedure_area    actual_worth
# 370      11,953.35000        85.75000 1,025,000.00000
# 371      14,656.59000       316.71000 4,641,888.00000
# 372       7,436.33000       161.37000 1,200,000.00000
# 379      22,983.56000       130.18000 2,992,000.00000
# 380      26,641.55000       130.06000 3,465,000.00000

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=flats_df6, x='trans_group_en', y='meter_sale_price')
plt.title('Box Plot of Actual Worth by Transaction Group')
plt.xlabel('Transaction Group')
plt.ylabel('Meter sale price')
plt.show()

# %%
sns.relplot(data=flats_df6, x='meter_sale_price', y='procedure_area', hue='trans_group_en')

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
sales_transaction_group = flats_df6[flats_df6['trans_group_en'] == 'Sales']
mortgage_transaction_group = flats_df6[flats_df6['trans_group_en'] == 'Mortgages']
gift_transaction_group = flats_df6[flats_df6['trans_group_en'] == 'Gifts']

sns.boxplot(
    data=sales_transaction_group,
    x='trans_group_en',
    y='meter_sale_price',
    ax=axes[0]
)

sns.boxplot(
    data=mortgage_transaction_group,
    x='trans_group_en',
    y='meter_sale_price',
    ax=axes[1]
)

sns.boxplot(
    data=gift_transaction_group,
    x='trans_group_en',
    y='meter_sale_price',
    ax=axes[2]
)

axes[0].set_title('Sales Transaction Group')
axes[1].set_title('Mortgage Transaction Group')
axes[2].set_title('Gift Transaction Group')

plt.tight_layout()
plt.show()

# %%
sales_transaction_group['meter_sale_price'].describe()
# Out:
# count      861,184.00000
# mean        17,419.52011
# std        128,745.31782
# min              0.01000
# 25%          9,746.95750
# 50%         14,449.05000
# 75%         20,514.23250
# max     81,250,000.00000
# Name: meter_sale_price, dtype: float64

# %%
mortgage_transaction_group['meter_sale_price'].describe()
# Out:
# count      137,942.00000
# mean        13,776.84794
# std        158,310.78757
# min              5.62000
# 25%          6,617.65000
# 50%          8,985.56500
# 75%         12,499.45750
# max     21,811,987.51000
# Name: meter_sale_price, dtype: float64

# %%
gift_transaction_group['meter_sale_price'].describe()
# Out:
# count    27,933.00000
# mean     13,212.73159
# std       6,740.47925
# min           1.50000
# 25%       8,171.48000
# 50%      11,556.94000
# 75%      16,939.22000
# max     125,428.53000
# Name: meter_sale_price, dtype: float64

# %% [markdown]
# The mean sale price for:
# 1. Sale properties is 16,825.9
# 2. Mortgage properties is 13,982
# 3. Gift properties is 12,714.8

# %%
12714/16825
# Out:
# 0.7556612184249628

# %%
sale_mean_price = sales_transaction_group['meter_sale_price'].mean()
gift_mean_price = gift_transaction_group['meter_sale_price'].mean()
percent = round(gift_mean_price / sale_mean_price, 2) * 100

print(f"Gift sale price on average are {percent}% of sale mean price")
# Out:
# Gift sale price on average are 76.0% of sale mean price

# %%
print(f"Total sales transactions: {len(sales_transaction_group)}")
print(f"Total gift transactions: {len(gift_transaction_group)}")

print(f"Sales tr percentage: {round(len(sales_transaction_group)/len(flats_df6), 2) * 100}")
print(f"Gift tr percentage: {round(len(gift_transaction_group)/len(flats_df6), 2) * 100}")
# Out:
# Total sales transactions: 861184
# Total gift transactions: 27933
# Sales tr percentage: 84.0
# Gift tr percentage: 3.0

# %%
# Since gift transactions are only 3 percent we, can remove them

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

q_low = flats_df6['meter_sale_price'].quantile(0.01)
q_high = flats_df6['meter_sale_price'].quantile(0.99)
filtered_df = flats_df6[(flats_df6['meter_sale_price'] >= q_low) & (flats_df6['meter_sale_price'] <= q_high)]

plt.figure(figsize=(8,6))
sns.boxplot(
    x='trans_group_en',
    y='meter_sale_price',
    data=filtered_df,
    showfliers=True,
    palette="Set2"
)


import matplotlib.ticker as mtick
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('AED{x:,.0f}'))

plt.title("Price per sq. m: Gifts vs Sales vs Mortgages", fontsize=14)
plt.xlabel("Transaction Type")
plt.ylabel("Price per sq. m")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/j5/b_yzj8c173n5bygl1tcrnw840000gn/T/ipykernel_39105/1359685233.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
flats_df7 = flats_df6[flats_df6['trans_group_en'] != 'Gifts']
print(f"With gift transactions, total = {len(flats_df6)}")
print(f"Without gift transactions, total = {len(flats_df7)}")
# Out:
# With gift transactions, total = 1027059
# Without gift transactions, total = 999126

# %%
flats_df7 = flats_df7.drop(columns=['trans_group_id'])

# %%
flats_df7.shape
# Out:
# (999126, 25)

# %%
print(f"{len(flats_df7)} Samples & {len(flats_df7.columns)} Features")
# Out:
# 999126 Samples & 25 Features

# %%
flats_df7[['trans_group_en', 'procedure_name_en']].head(10)
# Out:
#     trans_group_en          procedure_name_en
# 370          Sales                       Sell
# 371          Sales  Lease to Own Registration
# 372          Sales                       Sell
# 379          Sales    Sell - Pre registration
# 380          Sales    Sell - Pre registration
# 381          Sales    Sell - Pre registration
# 382          Sales    Sell - Pre registration
# 383          Sales    Sell - Pre registration
# 491          Sales    Sell - Pre registration
# 492          Sales    Sell - Pre registration

# %%
flats_df7.procedure_name_en.value_counts()
# Out:
# procedure_name_en
# Sell - Pre registration                       464877
# Sell                                          311336
# Mortgage Registration                         103423
# Delayed Sell                                   48057
# Lease to Own Registration                      37532
# Delayed Mortgage                                7935
# Sell Development                                7737
# Development Registration                        7345
# Lease to Own Registration Pre-Registration      6133
# Lease Finance Registration                      4751
# Name: count, dtype: int64

# %%
flats_df7.head()
# Out:
#      procedure_id trans_group_en          procedure_name_en  reg_type_id  \
# 370            11          Sales                       Sell            1
# 371           110          Sales  Lease to Own Registration            1
# 372            11          Sales                       Sell            1
# 379           102          Sales    Sell - Pre registration            0
# 380           102          Sales    Sell - Pre registration            0
#
#              reg_type_en  area_id    area_name_en building_name_en  \
# 370  Existing Properties      255  Rega Al Buteen    EMAAR TOWER 1
# 371  Existing Properties      255  Rega Al Buteen    EMAAR TOWER 1
# 372  Existing Properties      255  Rega Al Buteen    EMAAR TOWER 2
# 379  Off-Plan Properties      390    Burj Khalifa      VOLTA TOWER
# 380  Off-Plan Properties      390    Burj Khalifa      VOLTA TOWER
#
#      project_number project_name_en  ... has_parking procedure_area  \
# 370             NaN             NaN  ...           1       85.75000
# 371             NaN             NaN  ...           1      316.71000
# 372             NaN             NaN  ...           1      161.37000
# 379     2,782.00000     VOLTA TOWER  ...           1      130.18000
# 380     2,782.00000     VOLTA TOWER  ...           1      130.06000
#
#        actual_worth meter_sale_price rent_value  meter_rent_price  \
# 370 1,025,000.00000     11,953.35000        NaN               NaN
# 371 4,641,888.00000     14,656.59000        NaN               NaN
# 372 1,200,000.00000      7,436.33000        NaN               NaN
# 379 2,992,000.00000     22,983.56000        NaN               NaN
# 380 3,465,000.00000     26,641.55000        NaN               NaN
#
#      no_of_parties_role_1  no_of_parties_role_2  no_of_parties_role_3  \
# 370               1.00000               1.00000               0.00000
# 371               2.00000               2.00000               2.00000
# 372               1.00000               1.00000               0.00000
# 379               1.00000               2.00000               0.00000
# 380               1.00000               1.00000               0.00000
#
#      parsed_date
# 370   2016-02-15
# 371   2009-11-24
# 372   2018-05-01
# 379   2024-01-16
# 380   2024-05-07
#
# [5 rows x 25 columns]

# %%
flats_df7.reg_type_en.value_counts()
# Out:
# reg_type_en
# Existing Properties    528116
# Off-Plan Properties    471010
# Name: count, dtype: int64

# %%
# from sklearn.preprocessing import OneHotEncoder

# %%
# encoder = OneHotEncoder(sparse_output=False)
# encoded_reg_type = encoder.fit_transform(flats_df6[['reg_type_en']])

# %%
# print(encoded_reg_type)

# %%
# encoded_reg_type

# %%
# encoder.get_feature_names_out(['reg_type_en'])

# %%
# encoded_df = pd.DataFrame(encoded_reg_type, columns=encoder.get_feature_names_out(['reg_type_en']))
# encoded_df.head()

# %%
# flats_df7 = pd.concat([flats_df6.drop(columns=['reg_type_en', 'reg_type_id']), encoded_df], axis=1)

# %%
# flats_df7.head()
# len(flats_df7)

# %%
# area_names_df = flats_df7.area_name_en.value_counts().reset_index()
# area_names_df.shape

# %% [markdown]
# ## Area name en and id

# %%
mapping_check = flats_df7.groupby('area_id')['area_name_en'].nunique()
type(mapping_check)
# Out:
# pandas.Series

# %%
print(f"No. of conflicts: {len(mapping_check[mapping_check > 1])}")
# Out:
# No. of conflicts: 0

# %%
flats_df8 = flats_df7.drop(columns=['area_id'])

# %%
flats_df8.shape
# flats_df8.head()
# Out:
# (999126, 24)

# %%
def _clean_name(name):
  if pd.isna(name):
    return 'Unknown'
  return name.strip()

# %%
flats_df9 = flats_df8.drop(columns=['area_name_en'])
flats_df9['area_name_en'] = flats_df8['area_name_en'].apply(_clean_name)

# %%
flats_df9['area_name_en'].value_counts()
# Out:
# area_name_en
# Marsa Dubai                    119371
# Al Barsha South Fourth          87540
# Burj Khalifa                    66727
# Business Bay                    62566
# Al Thanyah Fifth                50058
#                                 ...
# Um Hurair Second                  176
# Al Qusais Industrial Fourth       169
# Nad Al Hamar                      133
# Al Qusais Industrial Fifth         72
# Hessyan Second                      3
# Name: count, Length: 72, dtype: int64

# %%
# area_name_en will use

# %% [markdown]
# `area_name_en` transformation will be done via OHE.

# %% [markdown]
# The project_number and project_name_en have a 1-1 mapping.

# %%
flats_df9 = flats_df9.drop(columns=['project_number'])

# %%
df_status(flats_df9)
# Out:
# 999,126 Samples & 23 Features

# %%
flats_df9.columns
# Out:
# Index(['procedure_id', 'trans_group_en', 'procedure_name_en', 'reg_type_id',
#        'reg_type_en', 'building_name_en', 'project_name_en',
#        'master_project_en', 'nearest_landmark_en', 'nearest_metro_en',
#        'nearest_mall_en', 'rooms_en', 'has_parking', 'procedure_area',
#        'actual_worth', 'meter_sale_price', 'rent_value', 'meter_rent_price',
#        'no_of_parties_role_1', 'no_of_parties_role_2', 'no_of_parties_role_3',
#        'parsed_date', 'area_name_en'],
#       dtype='str')

# %%
flats_df9['project_name_en'].value_counts()
# Out:
# project_name_en
# REMRAAM                          10840
# SKY COURTS                        9752
# INTERNATIONAL CITY EMARATI        4643
# LAKESIDE                          4159
# SEVEN CITY JLT                    3522
#                                  ...
# FORTUNE SERENE                       1
# THE ROYAL ESTATES PLOT.2             1
# Amazonia                             1
# RUFI PRIME VIEW                      1
# Barari Parkview by Al Mawared        1
# Name: count, Length: 2136, dtype: int64

# %%
without_project_name = flats_df9['project_name_en'].isna().sum()

# %%
print(f"There are a total of {without_project_name} Transactions without project name")
print(f"This is about {round(without_project_name/len(flats_df9),2)*100}%")
print("This can't be dropped, we need to mark them as unknown")
# Out:
# There are a total of 205099 Transactions without project name
# This is about 21.0%
# This can't be dropped, we need to mark them as unknown

# %%
flats_df9.drop(columns=['procedure_id'], inplace=True, errors='ignore')

# %%
flats_df9.columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_id', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'rooms_en', 'has_parking', 'procedure_area', 'actual_worth',
#        'meter_sale_price', 'rent_value', 'meter_rent_price',
#        'no_of_parties_role_1', 'no_of_parties_role_2', 'no_of_parties_role_3',
#        'parsed_date', 'area_name_en'],
#       dtype='str')

# %% [markdown]
# ## Area Name

# %%
flats_df9.area_name_en.nunique()
# Out:
# 72

# %%
print(f"Missing area names in data: {flats_df9.area_name_en.isna().sum()}")
# Out:
# Missing area names in data: 0

# %% [markdown]
# ## Building Name

# %% [markdown]
# # Categorical Features

# %%
flats_df9.select_dtypes(include=['str']).columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'rooms_en', 'area_name_en'],
#       dtype='str')

# %%
flats_df9.rooms_en.value_counts()
# Out:
# rooms_en
# 1 B/R          418138
# 2 B/R          274447
# Studio         203380
# 3 B/R           87764
# 4 B/R           11363
# 5 B/R            1470
# PENTHOUSE        1405
# Single Room       737
# 6 B/R             104
# Shop               41
# 7 B/R               7
# Office              6
# 9 B/R               3
# 8 B/R               2
# 10 B/R              1
# Name: count, dtype: int64

# %%
room_map = {
    '1 B/R': 1,
    '2 B/R': 2,
    '3 B/R': 3,
    '4 B/R': 4,
    '5 B/R': 5,
    '6 B/R': 6,
    '7 B/R': 7,
    '8 B/R': 8,
    '9 B/R': 9,
    'Studio': 1,
    'Penthouse': 5,
    'Single Room': 1,
    'Shop': -1,
    'Office': -1,
}
flats_df9['rooms_num'] = flats_df9.rooms_en.map(room_map)

# %%
flats_df9['rooms_num'].describe()
flats_df9.shape
# Out:
# (999126, 23)

# %%
flats_df9.columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_id', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'rooms_en', 'has_parking', 'procedure_area', 'actual_worth',
#        'meter_sale_price', 'rent_value', 'meter_rent_price',
#        'no_of_parties_role_1', 'no_of_parties_role_2', 'no_of_parties_role_3',
#        'parsed_date', 'area_name_en', 'rooms_num'],
#       dtype='str')

# %%
flats_df10 = flats_df9.drop(columns=['rooms_en'])

# %%
flats_df10.columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_id', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'has_parking', 'procedure_area', 'actual_worth', 'meter_sale_price',
#        'rent_value', 'meter_rent_price', 'no_of_parties_role_1',
#        'no_of_parties_role_2', 'no_of_parties_role_3', 'parsed_date',
#        'area_name_en', 'rooms_num'],
#       dtype='str')

# %%
(flats_df10.rooms_num == -1).sum()
# Out:
# np.int64(47)

# %%
flats_df10[flats_df10.rooms_num == -1].head()
# Out:
#        trans_group_en         procedure_name_en  reg_type_id  \
# 53113           Sales                      Sell            1
# 76571           Sales                      Sell            1
# 78279           Sales                      Sell            1
# 94669           Sales  Development Registration            1
# 104111      Mortgages     Mortgage Registration            1
#
#                 reg_type_en    building_name_en project_name_en  \
# 53113   Existing Properties  MARINA DIAMOND - B             NaN
# 76571   Existing Properties    MARINA DIAMOND-3             NaN
# 78279   Existing Properties         ALNAKHEEL 1             NaN
# 94669   Existing Properties            RITAJ  A           RITAJ
# 104111  Existing Properties         ALNAKHEEL 1             NaN
#
#                    master_project_en nearest_landmark_en     nearest_metro_en  \
# 53113                   Dubai Marina        Burj Al Arab         Dubai Marina
# 76571                   Dubai Marina        Burj Al Arab         Dubai Marina
# 78279                     The Greens        Burj Al Arab  Dubai Internet City
# 94669   Dubai Investment Park Second      Expo 2020 Site                  NaN
# 104111                    The Greens        Burj Al Arab  Dubai Internet City
#
#        nearest_mall_en  ...    actual_worth  meter_sale_price  rent_value  \
# 53113      Marina Mall  ...   800,000.00000      11,374.95000         NaN
# 76571      Marina Mall  ... 5,070,800.00000      30,138.48000         NaN
# 78279      Marina Mall  ... 1,200,000.00000       7,796.76000         NaN
# 94669              NaN  ...   436,100.00000       9,599.38000         NaN
# 104111     Marina Mall  ... 1,448,000.00000      10,761.80000         NaN
#
#         meter_rent_price  no_of_parties_role_1  no_of_parties_role_2  \
# 53113                NaN               1.00000               2.00000
# 76571                NaN               6.00000               1.00000
# 78279                NaN               2.00000               1.00000
# 94669                NaN               1.00000               1.00000
# 104111               NaN               1.00000               1.00000
#
#         no_of_parties_role_3  parsed_date                  area_name_en  \
# 53113                0.00000   2023-02-21                   Marsa Dubai
# 76571                0.00000   2008-07-22                   Marsa Dubai
# 78279                0.00000   2012-01-18              Al Thanyah Third
# 94669                0.00000   2013-04-10  Dubai Investment Park Second
# 104111               0.00000   2024-07-12              Al Thanyah Third
#
#        rooms_num
# 53113   -1.00000
# 76571   -1.00000
# 78279   -1.00000
# 94669   -1.00000
# 104111  -1.00000
#
# [5 rows x 22 columns]

# %%
# Drop samples with rooms_num = -1
flats_df11 = flats_df10[flats_df10.rooms_num != -1]

# %%
df_status(flats_df10)
df_status(flats_df11)
# Out:
# 999,126 Samples & 22 Features
# 999,079 Samples & 22 Features

# %%
building_counts = flats_df11.building_name_en.value_counts()
building_counts
# Out:
# building_name_en
# Seven City JLT               3522
# Burj Khalifa                 3060
# PRINCESS TOWER               2767
# Marina Pinnacle              2562
# ELITE RESIDENCE              2519
#                              ...
# Mirdad 2                        1
# AMBER                           1
# The Cape - B                    1
# The Palm Hotel and Resort       1
# Frond/JHFTA                     1
# Name: count, Length: 4369, dtype: int64

# %%
print(f"No. of unique buildings: {len(building_counts)}")
print(type(building_counts))
print(building_counts.describe())
plt.hist(building_counts)
plt.xlabel('No. of Buildings')
plt.ylabel('Frequency of transactions for those buildings')
# Out:
# No. of unique buildings: 4369
# <class 'pandas.Series'>
# count   4,369.00000
# mean      228.67453
# std       270.49674
# min         1.00000
# 25%        58.00000
# 50%       152.00000
# 75%       292.00000
# max     3,522.00000
# Name: count, dtype: float64
# Text(0, 0.5, 'Frequency of transactions for those buildings')

# %%
mean_count = building_counts.mean()
print(f"Mean count: {round(mean_count, 2)}")
# Out:
# Mean count: 228.67

# %%
flats_df11.building_name_en.isna().sum()
# Out:
# np.int64(0)

# %%
no_trans_group_transactions = len(flats_df11[flats_df11.trans_group_en.isna()])
transactions_with_trans_group = len(flats_df11[~flats_df11.trans_group_en.isna()])
print(f"Rows with trans_group_en is null : {no_trans_group_transactions}")
print(f"Rows with trans_group_en is not null : {transactions_with_trans_group}")
print(f"Percentage of rows with trans_group_en is null : {round((no_trans_group_transactions / len(flats_df10)) * 100, 2)}%")
# Out:
# Rows with trans_group_en is null : 0
# Rows with trans_group_en is not null : 999079
# Percentage of rows with trans_group_en is null : 0.0%

# %%
df_status(flats_df11)
# Out:
# 999,079 Samples & 22 Features

# %% [markdown]
# # One Hot Encoding Columns
#
# 1. trans_group_en
# 2. procedure_name_en
# 3. area_name_en
# 4. master_project_en
# 5. nearest_mall_en
# 6. nearest_metro_en
# 7. nearest_landmark_en

# %% [markdown]
# # Target Encoding Coumns
#
# 1. building_name_en
# 2. project_name_en

# %% [markdown]
# # Non Categorical Columns

# %%
non_categorical_columns = flats_df11.select_dtypes(exclude=['str']).columns

# %%
non_categorical_columns
# Out:
# Index(['reg_type_id', 'has_parking', 'procedure_area', 'actual_worth',
#        'meter_sale_price', 'rent_value', 'meter_rent_price',
#        'no_of_parties_role_1', 'no_of_parties_role_2', 'no_of_parties_role_3',
#        'parsed_date', 'rooms_num'],
#       dtype='str')

# %%
flats_df11.reg_type_id.value_counts()
# Out:
# reg_type_id
# 1    528069
# 0    471010
# Name: count, dtype: int64

# %%
flats_df11.reg_type_id.isna().sum()
# Out:
# np.int64(0)

# %%
flats_df11.reg_type_en.value_counts()
# Out:
# reg_type_en
# Existing Properties    528069
# Off-Plan Properties    471010
# Name: count, dtype: int64

# %%
flats_df12 = flats_df11.drop(columns=['reg_type_en'])
## Since both reg_type_en and reg_type_id represent same thing,
## we drop reg_type_id
df_status(flats_df12)
# Out:
# 999,079 Samples & 21 Features

# %%
flats_df12.has_parking.value_counts()
# Out:
# has_parking
# 1    934057
# 0     65022
# Name: count, dtype: int64

# %%
flats_df12[['procedure_area', 'meter_sale_price', 'actual_worth']]
# Out:
#          procedure_area  meter_sale_price    actual_worth
# 370            85.75000      11,953.35000 1,025,000.00000
# 371           316.71000      14,656.59000 4,641,888.00000
# 372           161.37000       7,436.33000 1,200,000.00000
# 379           130.18000      22,983.56000 2,992,000.00000
# 380           130.06000      26,641.55000 3,465,000.00000
# ...                 ...               ...             ...
# 1665083        68.45000      27,142.26000 1,857,888.00000
# 1665084       115.98000      37,402.03000 4,337,888.00000
# 1665093        72.24000       9,665.31000   698,222.00000
# 1665104        53.49000       4,544.79000   243,101.00000
# 1665107        85.72000      15,977.66000 1,369,605.00000
#
# [999079 rows x 3 columns]

# %%
flats_df11.actual_worth.value_counts()
# actual_worth is the y
# meter_sale_price is correlated with actual_worth inversely; should be dropped
# flats_df12 = flats_df11.drop(columns=['meter_sale_price'])
# Out:
# actual_worth
# 1,000,000.00000    6002
# 1,200,000.00000    5242
# 500,000.00000      4981
# 600,000.00000      4921
# 800,000.00000      4502
#                    ...
# 986,140.00000         1
# 1,115,097.00000       1
# 1,577,732.00000       1
# 1,171,224.00000       1
# 1,369,605.00000       1
# Name: count, Length: 229803, dtype: int64

# %%
flats_df11.shape
# Out:
# (999079, 22)

# %% [markdown]
# ### Dropping meter_rent_price
# Taking assumption that won't be available in final testing, so dropping the feature
#
# DROPPING LATER. BECAUSE OF SOME DEBUGGING

# %%
# flats_df12 = flats_df11.drop(columns=['meter_rent_price', 'rent_value'])
flats_df12 = flats_df11

# %%
flats_df12.head()
# Out:
#     trans_group_en          procedure_name_en  reg_type_id  \
# 370          Sales                       Sell            1
# 371          Sales  Lease to Own Registration            1
# 372          Sales                       Sell            1
# 379          Sales    Sell - Pre registration            0
# 380          Sales    Sell - Pre registration            0
#
#              reg_type_en building_name_en project_name_en master_project_en  \
# 370  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 371  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 372  Existing Properties    EMAAR TOWER 2             NaN               NaN
# 379  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
# 380  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
#
#              nearest_landmark_en                      nearest_metro_en  \
# 370  Dubai International Airport                Al Rigga Metro Station
# 371  Dubai International Airport                Al Rigga Metro Station
# 372  Dubai International Airport                Al Rigga Metro Station
# 379                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
# 380                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
#
#     nearest_mall_en  ...    actual_worth  meter_sale_price  rent_value  \
# 370      Dubai Mall  ... 1,025,000.00000      11,953.35000         NaN
# 371      Dubai Mall  ... 4,641,888.00000      14,656.59000         NaN
# 372      Dubai Mall  ... 1,200,000.00000       7,436.33000         NaN
# 379      Dubai Mall  ... 2,992,000.00000      22,983.56000         NaN
# 380      Dubai Mall  ... 3,465,000.00000      26,641.55000         NaN
#
#      meter_rent_price  no_of_parties_role_1  no_of_parties_role_2  \
# 370               NaN               1.00000               1.00000
# 371               NaN               2.00000               2.00000
# 372               NaN               1.00000               1.00000
# 379               NaN               1.00000               2.00000
# 380               NaN               1.00000               1.00000
#
#      no_of_parties_role_3  parsed_date    area_name_en rooms_num
# 370               0.00000   2016-02-15  Rega Al Buteen   1.00000
# 371               2.00000   2009-11-24  Rega Al Buteen   4.00000
# 372               0.00000   2018-05-01  Rega Al Buteen   3.00000
# 379               0.00000   2024-01-16    Burj Khalifa   2.00000
# 380               0.00000   2024-05-07    Burj Khalifa   2.00000
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Drop number of parties for registration

# %%
flats_df13 = flats_df12.drop(columns=['no_of_parties_role_1','no_of_parties_role_2', 'no_of_parties_role_3'])
df_status(flats_df13)
# Out:
# 999,079 Samples & 19 Features

# %% [markdown]
# # Final Number of Features before any encoding is 15 including target variable

# %%
flats_df13.head()
# Out:
#     trans_group_en          procedure_name_en  reg_type_id  \
# 370          Sales                       Sell            1
# 371          Sales  Lease to Own Registration            1
# 372          Sales                       Sell            1
# 379          Sales    Sell - Pre registration            0
# 380          Sales    Sell - Pre registration            0
#
#              reg_type_en building_name_en project_name_en master_project_en  \
# 370  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 371  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 372  Existing Properties    EMAAR TOWER 2             NaN               NaN
# 379  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
# 380  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
#
#              nearest_landmark_en                      nearest_metro_en  \
# 370  Dubai International Airport                Al Rigga Metro Station
# 371  Dubai International Airport                Al Rigga Metro Station
# 372  Dubai International Airport                Al Rigga Metro Station
# 379                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
# 380                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
#
#     nearest_mall_en  has_parking  procedure_area    actual_worth  \
# 370      Dubai Mall            1        85.75000 1,025,000.00000
# 371      Dubai Mall            1       316.71000 4,641,888.00000
# 372      Dubai Mall            1       161.37000 1,200,000.00000
# 379      Dubai Mall            1       130.18000 2,992,000.00000
# 380      Dubai Mall            1       130.06000 3,465,000.00000
#
#      meter_sale_price  rent_value  meter_rent_price parsed_date  \
# 370      11,953.35000         NaN               NaN  2016-02-15
# 371      14,656.59000         NaN               NaN  2009-11-24
# 372       7,436.33000         NaN               NaN  2018-05-01
# 379      22,983.56000         NaN               NaN  2024-01-16
# 380      26,641.55000         NaN               NaN  2024-05-07
#
#        area_name_en  rooms_num
# 370  Rega Al Buteen    1.00000
# 371  Rega Al Buteen    4.00000
# 372  Rega Al Buteen    3.00000
# 379    Burj Khalifa    2.00000
# 380    Burj Khalifa    2.00000

# %% [markdown]
# # Check Target Variable

# %%
flats_df13.actual_worth.describe()
# Out:
# count         999,079.00000
# mean        1,595,940.74494
# std         4,210,837.55606
# min                 1.00000
# 25%           652,000.00000
# 50%         1,087,500.00000
# 75%         1,823,828.00000
# max     3,013,326,074.00000
# Name: actual_worth, dtype: float64

# %%
sns.histplot(flats_df13['actual_worth'], bins=10, kde=True)
plt.show()

# %%
skewness = flats_df13['actual_worth'].skew()
print(f"Skewness: {skewness:.2f}")
# Out:
# Skewness: 382.56

# %%
low_priced_transactions = flats_df13[flats_df13['actual_worth'] < 300000][['actual_worth', 'meter_sale_price', 'parsed_date']].sort_values(by='parsed_date')

# %%
print(f"Total transactions lower than 300k: {len(low_priced_transactions)}")
# Out:
# Total transactions lower than 300k: 32487

# %%
MAX_ACTUAL_WORTH = flats_df13.actual_worth.quantile(0.99)
high_priced_transactions =  flats_df13[flats_df13['actual_worth']>MAX_ACTUAL_WORTH]

# %%
print(f"Total transactions greater than 99 quantile: {len(high_priced_transactions)}")
# Out:
# Total transactions greater than 99 quantile: 9991

# %%
# Remove low priced transactions
flats_df14 = flats_df13[flats_df13['actual_worth'] > 300000]

# %%
df_status(flats_df13)
df_status(flats_df14)
# Out:
# 999,079 Samples & 19 Features
# 963,750 Samples & 19 Features

# %%
flats_df15 = flats_df14[flats_df14['actual_worth'] < MAX_ACTUAL_WORTH]

# %%
df_status(flats_df14)
df_status(flats_df15)
# Out:
# 963,750 Samples & 19 Features
# 953,759 Samples & 19 Features

# %%
flats_df15['actual_worth_log'] = np.log1p(flats_df15['actual_worth'])
flats_df15.head()
# Out:
#     trans_group_en          procedure_name_en  reg_type_id  \
# 370          Sales                       Sell            1
# 371          Sales  Lease to Own Registration            1
# 372          Sales                       Sell            1
# 379          Sales    Sell - Pre registration            0
# 380          Sales    Sell - Pre registration            0
#
#              reg_type_en building_name_en project_name_en master_project_en  \
# 370  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 371  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 372  Existing Properties    EMAAR TOWER 2             NaN               NaN
# 379  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
# 380  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
#
#              nearest_landmark_en                      nearest_metro_en  \
# 370  Dubai International Airport                Al Rigga Metro Station
# 371  Dubai International Airport                Al Rigga Metro Station
# 372  Dubai International Airport                Al Rigga Metro Station
# 379                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
# 380                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
#
#     nearest_mall_en  has_parking  procedure_area    actual_worth  \
# 370      Dubai Mall            1        85.75000 1,025,000.00000
# 371      Dubai Mall            1       316.71000 4,641,888.00000
# 372      Dubai Mall            1       161.37000 1,200,000.00000
# 379      Dubai Mall            1       130.18000 2,992,000.00000
# 380      Dubai Mall            1       130.06000 3,465,000.00000
#
#      meter_sale_price  rent_value  meter_rent_price parsed_date  \
# 370      11,953.35000         NaN               NaN  2016-02-15
# 371      14,656.59000         NaN               NaN  2009-11-24
# 372       7,436.33000         NaN               NaN  2018-05-01
# 379      22,983.56000         NaN               NaN  2024-01-16
# 380      26,641.55000         NaN               NaN  2024-05-07
#
#        area_name_en  rooms_num  actual_worth_log
# 370  Rega Al Buteen    1.00000          13.84020
# 371  Rega Al Buteen    4.00000          15.35063
# 372  Rega Al Buteen    3.00000          13.99783
# 379    Burj Khalifa    2.00000          14.91145
# 380    Burj Khalifa    2.00000          15.05822

# %%
sns.histplot(flats_df15['actual_worth_log'], bins=30, kde=True)
plt.xlabel("Log(Price)")
plt.show()

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()

# %%
# flats_df14['actual_worth_scaled'] = scaler.fit_transform(
#     flats_df14[['actual_worth_log']]
# )
# flats_df14.head()

# %%
# flats_df14.actual_worth_scaled.describe()

# %%
# import joblib

# joblib.dump(scaler, 'actual_worth_log_scaler.pkl')

# %%
# import joblib

# # Load the scaler
# scaler = joblib.load('scaler.pkl')

# # Inverse transform
# original_log_values = scaler.inverse_transform(flats_df14[['actual_worth_scaled']])
# original_values = np.expm1(original_log_values)

# %%
flats_df15['actual_worth_non_log'] = np.expm1(flats_df15['actual_worth_log'])
flats_df15.head()
# Out:
#     trans_group_en          procedure_name_en  reg_type_id  \
# 370          Sales                       Sell            1
# 371          Sales  Lease to Own Registration            1
# 372          Sales                       Sell            1
# 379          Sales    Sell - Pre registration            0
# 380          Sales    Sell - Pre registration            0
#
#              reg_type_en building_name_en project_name_en master_project_en  \
# 370  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 371  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 372  Existing Properties    EMAAR TOWER 2             NaN               NaN
# 379  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
# 380  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
#
#              nearest_landmark_en                      nearest_metro_en  \
# 370  Dubai International Airport                Al Rigga Metro Station
# 371  Dubai International Airport                Al Rigga Metro Station
# 372  Dubai International Airport                Al Rigga Metro Station
# 379                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
# 380                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
#
#     nearest_mall_en  ...  procedure_area    actual_worth  meter_sale_price  \
# 370      Dubai Mall  ...        85.75000 1,025,000.00000      11,953.35000
# 371      Dubai Mall  ...       316.71000 4,641,888.00000      14,656.59000
# 372      Dubai Mall  ...       161.37000 1,200,000.00000       7,436.33000
# 379      Dubai Mall  ...       130.18000 2,992,000.00000      22,983.56000
# 380      Dubai Mall  ...       130.06000 3,465,000.00000      26,641.55000
#
#      rent_value  meter_rent_price  parsed_date    area_name_en rooms_num  \
# 370         NaN               NaN   2016-02-15  Rega Al Buteen   1.00000
# 371         NaN               NaN   2009-11-24  Rega Al Buteen   4.00000
# 372         NaN               NaN   2018-05-01  Rega Al Buteen   3.00000
# 379         NaN               NaN   2024-01-16    Burj Khalifa   2.00000
# 380         NaN               NaN   2024-05-07    Burj Khalifa   2.00000
#
#      actual_worth_log  actual_worth_non_log
# 370          13.84020       1,025,000.00000
# 371          15.35063       4,641,888.00000
# 372          13.99783       1,200,000.00000
# 379          14.91145       2,992,000.00000
# 380          15.05822       3,465,000.00000
#
# [5 rows x 21 columns]

# %%
flats_df16 = flats_df15.drop(columns=['actual_worth', 'actual_worth_non_log'])

# %%
flats_df16.head()
# Out:
#     trans_group_en          procedure_name_en  reg_type_id  \
# 370          Sales                       Sell            1
# 371          Sales  Lease to Own Registration            1
# 372          Sales                       Sell            1
# 379          Sales    Sell - Pre registration            0
# 380          Sales    Sell - Pre registration            0
#
#              reg_type_en building_name_en project_name_en master_project_en  \
# 370  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 371  Existing Properties    EMAAR TOWER 1             NaN               NaN
# 372  Existing Properties    EMAAR TOWER 2             NaN               NaN
# 379  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
# 380  Off-Plan Properties      VOLTA TOWER     VOLTA TOWER               NaN
#
#              nearest_landmark_en                      nearest_metro_en  \
# 370  Dubai International Airport                Al Rigga Metro Station
# 371  Dubai International Airport                Al Rigga Metro Station
# 372  Dubai International Airport                Al Rigga Metro Station
# 379                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
# 380                 Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
#
#     nearest_mall_en  has_parking  procedure_area  meter_sale_price  \
# 370      Dubai Mall            1        85.75000      11,953.35000
# 371      Dubai Mall            1       316.71000      14,656.59000
# 372      Dubai Mall            1       161.37000       7,436.33000
# 379      Dubai Mall            1       130.18000      22,983.56000
# 380      Dubai Mall            1       130.06000      26,641.55000
#
#      rent_value  meter_rent_price parsed_date    area_name_en  rooms_num  \
# 370         NaN               NaN  2016-02-15  Rega Al Buteen    1.00000
# 371         NaN               NaN  2009-11-24  Rega Al Buteen    4.00000
# 372         NaN               NaN  2018-05-01  Rega Al Buteen    3.00000
# 379         NaN               NaN  2024-01-16    Burj Khalifa    2.00000
# 380         NaN               NaN  2024-05-07    Burj Khalifa    2.00000
#
#      actual_worth_log
# 370          13.84020
# 371          15.35063
# 372          13.99783
# 379          14.91145
# 380          15.05822

# %% [markdown]
# # Feature Columns

# %% [markdown]
# ## Handling Null Values

# %%
flats_df16.columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_id', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'has_parking', 'procedure_area', 'meter_sale_price', 'rent_value',
#        'meter_rent_price', 'parsed_date', 'area_name_en', 'rooms_num',
#        'actual_worth_log'],
#       dtype='str')

# %%
flats_df16.isnull().mean() * 100
# Out:
# trans_group_en         0.00000
# procedure_name_en      0.00000
# reg_type_id            0.00000
# reg_type_en            0.00000
# building_name_en       0.00000
# project_name_en       19.38624
# master_project_en      5.67428
# nearest_landmark_en   14.70728
# nearest_metro_en      23.04104
# nearest_mall_en       23.52439
# has_parking            0.00000
# procedure_area         0.00000
# meter_sale_price       0.00000
# rent_value            97.86005
# meter_rent_price      97.86005
# parsed_date            0.00000
# area_name_en           0.00000
# rooms_num              0.15968
# actual_worth_log       0.00000
# dtype: float64

# %%
flats_df16.columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_id', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'has_parking', 'procedure_area', 'meter_sale_price', 'rent_value',
#        'meter_rent_price', 'parsed_date', 'area_name_en', 'rooms_num',
#        'actual_worth_log'],
#       dtype='str')

# %%
flats_df16[flats_df16.master_project_en == 'Dubai Marina'].head(20)
# Out:
#     trans_group_en          procedure_name_en  reg_type_id  \
# 560          Sales                       Sell            1
# 561          Sales                       Sell            1
# 562          Sales                       Sell            1
# 563          Sales                       Sell            1
# 565          Sales                       Sell            1
# 566          Sales                       Sell            1
# 567          Sales                       Sell            1
# 568      Mortgages      Mortgage Registration            1
# 569          Sales                       Sell            1
# 570          Sales                       Sell            1
# 571          Sales                       Sell            1
# 572      Mortgages      Mortgage Registration            1
# 573      Mortgages      Mortgage Registration            1
# 574          Sales                       Sell            1
# 575      Mortgages      Mortgage Registration            1
# 576          Sales                       Sell            1
# 577      Mortgages      Mortgage Registration            1
# 578          Sales                       Sell            1
# 579          Sales                       Sell            1
# 642      Mortgages  Lease to Own Registration            1
#
#              reg_type_en    building_name_en project_name_en  \
# 560  Existing Properties  MARINA CROWN TOWER             NaN
# 561  Existing Properties  MARINA CROWN TOWER             NaN
# 562  Existing Properties  MARINA CROWN TOWER             NaN
# 563  Existing Properties  MARINA CROWN TOWER             NaN
# 565  Existing Properties  MARINA CROWN TOWER             NaN
# 566  Existing Properties  MARINA CROWN TOWER             NaN
# 567  Existing Properties  MARINA CROWN TOWER             NaN
# 568  Existing Properties  MARINA CROWN TOWER             NaN
# 569  Existing Properties  MARINA CROWN TOWER             NaN
# 570  Existing Properties  MARINA CROWN TOWER             NaN
# 571  Existing Properties  MARINA CROWN TOWER             NaN
# 572  Existing Properties  MARINA CROWN TOWER             NaN
# 573  Existing Properties  MARINA CROWN TOWER             NaN
# 574  Existing Properties  MARINA CROWN TOWER             NaN
# 575  Existing Properties  MARINA CROWN TOWER             NaN
# 576  Existing Properties  MARINA CROWN TOWER             NaN
# 577  Existing Properties  MARINA CROWN TOWER             NaN
# 578  Existing Properties  MARINA CROWN TOWER             NaN
# 579  Existing Properties  MARINA CROWN TOWER             NaN
# 642  Existing Properties      PRINCESS TOWER  PRINCESS TOWER
#
#     master_project_en nearest_landmark_en nearest_metro_en nearest_mall_en  \
# 560      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 561      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 562      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 563      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 565      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 566      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 567      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 568      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 569      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 570      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 571      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 572      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 573      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 574      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 575      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 576      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 577      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 578      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 579      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
# 642      Dubai Marina        Burj Al Arab      Mina Seyahi     Marina Mall
#
#      has_parking  procedure_area  meter_sale_price      rent_value  \
# 560            1        70.08000       5,795.79000             NaN
# 561            1        83.59000       5,795.78000             NaN
# 562            1       125.14000      10,148.63000             NaN
# 563            1        69.67000      18,659.39000             NaN
# 565            1       135.35000       5,795.81000             NaN
# 566            1       449.10000      10,688.04000             NaN
# 567            1       201.93000      12,875.75000             NaN
# 568            1       159.25000       7,912.09000             NaN
# 569            1       159.25000       5,795.81000             NaN
# 570            1       131.13000       5,795.78000             NaN
# 571            1        78.29000       7,663.81000             NaN
# 572            1        68.00000       7,169.12000             NaN
# 573            1       201.93000       9,037.79000             NaN
# 574            1        68.00000       5,795.78000             NaN
# 575            1       138.77000      10,205.09000             NaN
# 576            1       135.35000      14,222.39000             NaN
# 577            1        77.90000       9,512.20000             NaN
# 578            1       201.93000       5,795.79000             NaN
# 579            1        83.59000       9,630.34000             NaN
# 642            1       122.04000      10,140.12000 1,237,500.00000
#
#      meter_rent_price parsed_date area_name_en  rooms_num  actual_worth_log
# 560               NaN  2007-10-04  Marsa Dubai    1.00000          12.91453
# 561               NaN  2007-10-01  Marsa Dubai    1.00000          13.09081
# 562               NaN  2021-06-24  Marsa Dubai    2.00000          14.05453
# 563               NaN  2008-11-03  Marsa Dubai    1.00000          14.07788
# 565               NaN  2007-08-23  Marsa Dubai    2.00000          13.57276
# 566               NaN  2020-11-19  Marsa Dubai    4.00000          15.38413
# 567               NaN  2013-09-30  Marsa Dubai    3.00000          14.77102
# 568               NaN  2015-09-21  Marsa Dubai    2.00000          14.04662
# 569               NaN  2007-10-04  Marsa Dubai    2.00000          13.73537
# 570               NaN  2007-10-01  Marsa Dubai    2.00000          13.54108
# 571               NaN  2011-07-18  Marsa Dubai    1.00000          13.30469
# 572               NaN  2018-01-16  Marsa Dubai    1.00000          13.09705
# 573               NaN  2016-03-21  Marsa Dubai    3.00000          14.41709
# 574               NaN  2007-10-01  Marsa Dubai    1.00000          12.88440
# 575               NaN  2024-04-04  Marsa Dubai    2.00000          14.16346
# 576               NaN  2023-06-07  Marsa Dubai    2.00000          14.47044
# 577               NaN  2018-02-15  Marsa Dubai    1.00000          13.51576
# 578               NaN  2007-08-27  Marsa Dubai    3.00000          13.97281
# 579               NaN  2022-05-30  Marsa Dubai    1.00000          13.59860
# 642      10,140.12000  2017-04-25  Marsa Dubai    2.00000          14.02860

# %%
flats_df16.project_name_en.value_counts()
# Out:
# project_name_en
# REMRAAM                          10496
# SKY COURTS                        8558
# INTERNATIONAL CITY EMARATI        3925
# SEVEN CITY JLT                    3517
# LAKESIDE                          3478
#                                  ...
# THE ROYAL ESTATES PLOT.2             1
# Amazonia                             1
# RUFI PRIME VIEW                      1
# ONE CANAL                            1
# Barari Parkview by Al Mawared        1
# Name: count, Length: 2100, dtype: int64

# %%
flats_df16[flats_df16.project_name_en == 'SKY COURTS'].head(50)
# Out:
#       trans_group_en                           procedure_name_en  reg_type_id  \
# 12922      Mortgages                  Lease Finance Registration            1
# 12923          Sales                   Lease to Own Registration            1
# 12924          Sales                   Lease to Own Registration            1
# 12925          Sales                                        Sell            1
# 12926      Mortgages  Lease to Own Registration Pre-Registration            0
# 12928          Sales                                        Sell            1
# 12929      Mortgages                   Lease to Own Registration            1
# 12930      Mortgages  Lease to Own Registration Pre-Registration            0
# 12931      Mortgages                   Lease to Own Registration            1
# 12933          Sales  Lease to Own Registration Pre-Registration            0
# 12934          Sales                                        Sell            1
# 12936          Sales                     Sell - Pre registration            0
# 12937      Mortgages                       Mortgage Registration            1
# 12939      Mortgages                   Lease to Own Registration            1
# 12940      Mortgages  Lease to Own Registration Pre-Registration            0
# 12941      Mortgages                       Mortgage Registration            1
# 12942          Sales                   Lease to Own Registration            1
# 12943      Mortgages                   Lease to Own Registration            1
# 12945          Sales                                        Sell            1
# 12947          Sales                                        Sell            1
# 12948      Mortgages  Lease to Own Registration Pre-Registration            0
# 12949          Sales                                        Sell            1
# 12950      Mortgages                   Lease to Own Registration            1
# 12951          Sales                     Sell - Pre registration            0
# 12953      Mortgages                   Lease to Own Registration            1
# 12954          Sales                     Sell - Pre registration            0
# 12955      Mortgages                   Lease to Own Registration            1
# 12956          Sales                                        Sell            1
# 12957          Sales  Lease to Own Registration Pre-Registration            0
# 12958      Mortgages  Lease to Own Registration Pre-Registration            0
# 12959      Mortgages                   Lease to Own Registration            1
# 12960          Sales                     Sell - Pre registration            0
# 12961          Sales                                        Sell            1
# 12962          Sales                     Sell - Pre registration            0
# 12963          Sales                                        Sell            1
# 12964          Sales                     Sell - Pre registration            0
# 12966      Mortgages                       Mortgage Registration            1
# 12967          Sales  Lease to Own Registration Pre-Registration            0
# 12968          Sales                   Lease to Own Registration            1
# 12970      Mortgages                   Lease to Own Registration            1
# 12971      Mortgages                   Lease to Own Registration            1
# 12972          Sales                                        Sell            1
# 12974          Sales                   Lease to Own Registration            1
# 12975      Mortgages                       Mortgage Registration            1
# 12976          Sales                                        Sell            1
# 12977          Sales                                        Sell            1
# 12978          Sales  Lease to Own Registration Pre-Registration            0
# 12979          Sales                     Sell - Pre registration            0
# 12980          Sales  Lease to Own Registration Pre-Registration            0
# 12982          Sales                                        Sell            1
#
#                reg_type_en   building_name_en project_name_en  \
# 12922  Existing Properties  Skycourts Tower A      SKY COURTS
# 12923  Existing Properties  Skycourts Tower A      SKY COURTS
# 12924  Existing Properties  Skycourts Tower A      SKY COURTS
# 12925  Existing Properties  Skycourts Tower A      SKY COURTS
# 12926  Off-Plan Properties  Skycourts Tower A      SKY COURTS
# 12928  Existing Properties  Skycourts Tower A      SKY COURTS
# 12929  Existing Properties  Skycourts Tower A      SKY COURTS
# 12930  Off-Plan Properties  Skycourts Tower A      SKY COURTS
# 12931  Existing Properties  Skycourts Tower A      SKY COURTS
# 12933  Off-Plan Properties  Skycourts Tower A      SKY COURTS
# 12934  Existing Properties  Skycourts Tower A      SKY COURTS
# 12936  Off-Plan Properties  Skycourts Tower A      SKY COURTS
# 12937  Existing Properties  Skycourts Tower A      SKY COURTS
# 12939  Existing Properties  Skycourts Tower A      SKY COURTS
# 12940  Off-Plan Properties  Skycourts Tower A      SKY COURTS
# 12941  Existing Properties  Skycourts Tower A      SKY COURTS
# 12942  Existing Properties  Skycourts Tower A      SKY COURTS
# 12943  Existing Properties  Skycourts Tower A      SKY COURTS
# 12945  Existing Properties  Skycourts Tower B      SKY COURTS
# 12947  Existing Properties  Skycourts Tower B      SKY COURTS
# 12948  Off-Plan Properties  Skycourts Tower B      SKY COURTS
# 12949  Existing Properties  Skycourts Tower B      SKY COURTS
# 12950  Existing Properties  Skycourts Tower B      SKY COURTS
# 12951  Off-Plan Properties  Skycourts Tower B      SKY COURTS
# 12953  Existing Properties  Skycourts Tower B      SKY COURTS
# 12954  Off-Plan Properties  Skycourts Tower B      SKY COURTS
# 12955  Existing Properties  Skycourts Tower B      SKY COURTS
# 12956  Existing Properties  Skycourts Tower B      SKY COURTS
# 12957  Off-Plan Properties  Skycourts Tower B      SKY COURTS
# 12958  Off-Plan Properties  Skycourts Tower B      SKY COURTS
# 12959  Existing Properties  Skycourts Tower B      SKY COURTS
# 12960  Off-Plan Properties  Skycourts Tower B      SKY COURTS
# 12961  Existing Properties  Skycourts Tower B      SKY COURTS
# 12962  Off-Plan Properties  Skycourts Tower B      SKY COURTS
# 12963  Existing Properties  Skycourts Tower B      SKY COURTS
# 12964  Off-Plan Properties  Skycourts Tower B      SKY COURTS
# 12966  Existing Properties  Skycourts Tower C      SKY COURTS
# 12967  Off-Plan Properties  Skycourts Tower C      SKY COURTS
# 12968  Existing Properties  Skycourts Tower C      SKY COURTS
# 12970  Existing Properties  Skycourts Tower C      SKY COURTS
# 12971  Existing Properties  Skycourts Tower C      SKY COURTS
# 12972  Existing Properties  Skycourts Tower C      SKY COURTS
# 12974  Existing Properties  Skycourts Tower C      SKY COURTS
# 12975  Existing Properties  Skycourts Tower C      SKY COURTS
# 12976  Existing Properties  Skycourts Tower C      SKY COURTS
# 12977  Existing Properties  Skycourts Tower C      SKY COURTS
# 12978  Off-Plan Properties  Skycourts Tower C      SKY COURTS
# 12979  Off-Plan Properties  Skycourts Tower C      SKY COURTS
# 12980  Off-Plan Properties  Skycourts Tower C      SKY COURTS
# 12982  Existing Properties  Skycourts Tower C      SKY COURTS
#
#                   master_project_en   nearest_landmark_en nearest_metro_en  \
# 12922  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12923  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12924  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12925  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12926  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12928  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12929  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12930  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12931  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12933  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12934  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12936  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12937  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12939  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12940  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12941  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12942  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12943  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12945  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12947  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12948  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12949  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12950  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12951  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12953  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12954  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12955  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12956  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12957  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12958  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12959  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12960  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12961  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12962  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12963  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12964  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12966  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12967  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12968  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12970  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12971  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12972  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12974  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12975  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12976  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12977  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12978  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12979  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12980  Dubai Land Residence Complex  IMG World Adventures              NaN
# 12982  Dubai Land Residence Complex  IMG World Adventures              NaN
#
#       nearest_mall_en  has_parking  procedure_area  meter_sale_price  \
# 12922             NaN            1       114.92000       5,597.22000
# 12923             NaN            1       114.92000       7,062.53000
# 12924             NaN            1        79.17000       6,804.99000
# 12925             NaN            1       118.09000       5,812.90000
# 12926             NaN            1        78.87000       8,818.31000
# 12928             NaN            1        41.00000       7,926.83000
# 12929             NaN            1        79.17000       6,804.99000
# 12930             NaN            1       116.61000       7,227.87000
# 12931             NaN            1        78.29000       7,456.35000
# 12933             NaN            1        77.79000       9,615.53000
# 12934             NaN            1       118.09000       7,348.76000
# 12936             NaN            1       113.51000       7,425.26000
# 12937             NaN            1        78.29000       4,623.20000
# 12939             NaN            1        79.17000       4,240.04000
# 12940             NaN            1        64.87000       7,392.44000
# 12941             NaN            1        68.18000       7,098.86000
# 12942             NaN            1        65.47000       7,324.70000
# 12943             NaN            1        65.47000      11,126.62000
# 12945             NaN            1        98.73000       6,381.04000
# 12947             NaN            1        78.29000       6,769.70000
# 12948             NaN            1       119.23000       7,041.96000
# 12949             NaN            1       119.53000       7,362.17000
# 12950             NaN            1        78.29000       7,424.58000
# 12951             NaN            1       100.54000       7,082.32000
# 12953             NaN            1       101.65000       7,004.98000
# 12954             NaN            1        77.79000       7,693.70000
# 12955             NaN            1       101.65000       7,212.52000
# 12956             NaN            1       119.53000       8,575.25000
# 12957             NaN            1       116.61000       7,442.03000
# 12958             NaN            1       115.85000       7,212.57000
# 12959             NaN            1        78.29000       4,636.61000
# 12960             NaN            1       119.23000       7,312.80000
# 12961             NaN            1       119.53000       8,240.61000
# 12962             NaN            1        67.58000       7,638.36000
# 12963             NaN            1        32.75000      12,061.07000
# 12964             NaN            1        97.83000       7,278.50000
# 12966             NaN            1        68.18000       5,921.82000
# 12967             NaN            1        97.83000       7,008.93000
# 12968             NaN            1        39.75000       8,830.19000
# 12970             NaN            1        78.29000       7,053.35000
# 12971             NaN            1       117.19000       5,973.21000
# 12972             NaN            1        78.29000       7,599.95000
# 12974             NaN            1       119.53000       7,529.49000
# 12975             NaN            1       119.53000       5,320.84000
# 12976             NaN            1       119.53000       4,559.52000
# 12977             NaN            1        50.77000       6,890.65000
# 12978             NaN            1       115.85000       6,945.43000
# 12979             NaN            1       116.61000       7,227.87000
# 12980             NaN            1        40.70000       7,497.96000
# 12982             NaN            1       115.86000       5,812.91000
#
#          rent_value  meter_rent_price parsed_date    area_name_en  rooms_num  \
# 12922           NaN               NaN  2017-12-25  Wadi Al Safa 5    2.00000
# 12923           NaN               NaN  2012-10-08  Wadi Al Safa 5    2.00000
# 12924           NaN               NaN  2012-08-30  Wadi Al Safa 5    1.00000
# 12925           NaN               NaN  2020-06-15  Wadi Al Safa 5    2.00000
# 12926 695,500.00000       8,818.31000  2009-07-16  Wadi Al Safa 5    1.00000
# 12928           NaN               NaN  2013-06-18  Wadi Al Safa 5    1.00000
# 12929 538,751.35000       6,804.99000  2015-12-07  Wadi Al Safa 5    1.00000
# 12930 842,841.77000       7,227.87000  2009-10-26  Wadi Al Safa 5    2.00000
# 12931 583,758.00000       7,456.35000  2011-06-07  Wadi Al Safa 5    1.00000
# 12933           NaN               NaN  2009-07-16  Wadi Al Safa 5    1.00000
# 12934           NaN               NaN  2012-12-13  Wadi Al Safa 5    2.00000
# 12936           NaN               NaN  2009-09-14  Wadi Al Safa 5    2.00000
# 12937           NaN               NaN  2019-01-24  Wadi Al Safa 5    1.00000
# 12939 335,684.00000       4,240.04000  2011-10-19  Wadi Al Safa 5    1.00000
# 12940 479,547.90000       7,392.44000  2009-10-26  Wadi Al Safa 5    1.00000
# 12941           NaN               NaN  2018-10-29  Wadi Al Safa 5    1.00000
# 12942           NaN               NaN  2016-02-16  Wadi Al Safa 5    1.00000
# 12943 728,460.00000      11,126.62000  2011-12-14  Wadi Al Safa 5    1.00000
# 12945           NaN               NaN  2018-11-20  Wadi Al Safa 5    2.00000
# 12947           NaN               NaN  2024-11-14  Wadi Al Safa 5    1.00000
# 12948 839,612.49000       7,041.96000  2009-10-26  Wadi Al Safa 5    2.00000
# 12949           NaN               NaN  2016-11-17  Wadi Al Safa 5    2.00000
# 12950 581,270.18000       7,424.58000  2013-07-16  Wadi Al Safa 5    1.00000
# 12951           NaN               NaN  2009-09-14  Wadi Al Safa 5    2.00000
# 12953 712,055.97000       7,004.98000  2013-08-13  Wadi Al Safa 5    2.00000
# 12954           NaN               NaN  2009-09-14  Wadi Al Safa 5    1.00000
# 12955 733,153.00000       7,212.52000  2014-04-21  Wadi Al Safa 5    2.00000
# 12956           NaN               NaN  2025-10-10  Wadi Al Safa 5    2.00000
# 12957           NaN               NaN  2009-10-26  Wadi Al Safa 5    2.00000
# 12958 835,575.89000       7,212.57000  2009-10-26  Wadi Al Safa 5    2.00000
# 12959 363,000.00000       4,636.61000  2017-03-23  Wadi Al Safa 5    1.00000
# 12960           NaN               NaN  2009-09-14  Wadi Al Safa 5    2.00000
# 12961           NaN               NaN  2026-01-23  Wadi Al Safa 5    2.00000
# 12962           NaN               NaN  2009-09-14  Wadi Al Safa 5    1.00000
# 12963           NaN               NaN  2014-05-12  Wadi Al Safa 5    1.00000
# 12964           NaN               NaN  2009-09-14  Wadi Al Safa 5    2.00000
# 12966           NaN               NaN  2013-09-16  Wadi Al Safa 5    1.00000
# 12967           NaN               NaN  2009-10-27  Wadi Al Safa 5    2.00000
# 12968           NaN               NaN  2016-02-16  Wadi Al Safa 5    1.00000
# 12970 552,206.68000       7,053.35000  2013-02-19  Wadi Al Safa 5    1.00000
# 12971 700,000.00000       5,973.21000  2014-04-24  Wadi Al Safa 5    2.00000
# 12972           NaN               NaN  2025-04-17  Wadi Al Safa 5    1.00000
# 12974           NaN               NaN  2013-08-26  Wadi Al Safa 5    2.00000
# 12975           NaN               NaN  2018-03-27  Wadi Al Safa 5    2.00000
# 12976           NaN               NaN  2022-06-21  Wadi Al Safa 5    2.00000
# 12977           NaN               NaN  2012-02-15  Wadi Al Safa 5    1.00000
# 12978           NaN               NaN  2009-10-26  Wadi Al Safa 5    2.00000
# 12979           NaN               NaN  2009-09-14  Wadi Al Safa 5    2.00000
# 12980           NaN               NaN  2009-10-26  Wadi Al Safa 5    1.00000
# 12982           NaN               NaN  2020-06-16  Wadi Al Safa 5    2.00000
#
#        actual_worth_log
# 12922          13.37426
# 12923          13.60679
# 12924          13.19701
# 12925          13.43928
# 12926          13.45239
# 12928          12.69158
# 12929          13.19701
# 12930          13.64453
# 12931          13.27724
# 12933          13.52515
# 12934          13.67373
# 12936          13.64453
# 12937          12.79926
# 12939          12.72393
# 12940          13.08060
# 12941          13.08984
# 12942          13.08060
# 12943          13.49869
# 12945          13.35348
# 12947          13.18063
# 12948          13.64070
# 12949          13.68768
# 12950          13.27297
# 12951          13.47591
# 12953          13.47591
# 12954          13.30217
# 12955          13.50511
# 12956          13.84020
# 12957          13.67373
# 12958          13.63588
# 12959          12.80216
# 12960          13.67844
# 12961          13.80040
# 12962          13.15425
# 12963          12.88664
# 12964          13.47591
# 12966          12.90855
# 12967          13.43817
# 12968          12.76854
# 12970          13.22168
# 12971          13.45884
# 12972          13.29632
# 12974          13.71015
# 12975          13.36296
# 12976          13.20854
# 12977          12.76523
# 12978          13.59814
# 12979          13.64453
# 12980          12.62861
# 12982          13.42022

# %%
flats_df16[['building_name_en', 'project_name_en', 'master_project_en']]
# Out:
#           building_name_en project_name_en    master_project_en
# 370          EMAAR TOWER 1             NaN                  NaN
# 371          EMAAR TOWER 1             NaN                  NaN
# 372          EMAAR TOWER 2             NaN                  NaN
# 379            VOLTA TOWER     VOLTA TOWER                  NaN
# 380            VOLTA TOWER     VOLTA TOWER                  NaN
# ...                    ...             ...                  ...
# 1665082  Creek Bay Tower A       Creek Bay  Dubai Creek Harbour
# 1665083  Creek Bay Tower A       Creek Bay  Dubai Creek Harbour
# 1665084  Creek Bay Tower A       Creek Bay  Dubai Creek Harbour
# 1665093       THE NOOK 1-1        The Nook            Wasl Gate
# 1665107             NOBLES          NOBLES         Business Bay
#
# [953759 rows x 3 columns]

# %%
# Handle missing  project name

flats_df16[flats_df16.master_project_en.isna() & flats_df16.project_name_en.isna()]
flats_df17 = flats_df16.copy()
flats_df17['project_name_en'] = flats_df16['project_name_en'].fillna(flats_df16['building_name_en'])

# %%
flats_df17.project_name_en.isna().sum()
# Out:
# np.int64(0)

# %%
flats_df18 = flats_df17.copy()
flats_df18['master_project_en'] = flats_df17['master_project_en'].fillna(flats_df17['project_name_en'])

# %%
flats_df18.isna().sum()
# Out:
# trans_group_en              0
# procedure_name_en           0
# reg_type_id                 0
# reg_type_en                 0
# building_name_en            0
# project_name_en             0
# master_project_en           0
# nearest_landmark_en    140272
# nearest_metro_en       219756
# nearest_mall_en        224366
# has_parking                 0
# procedure_area              0
# meter_sale_price            0
# rent_value             933349
# meter_rent_price       933349
# parsed_date                 0
# area_name_en                0
# rooms_num                1523
# actual_worth_log            0
# dtype: int64

# %%
flats_df18.nearest_landmark_en.value_counts()
# Out:
# nearest_landmark_en
# Sports City Swimming Academy         215631
# Burj Al Arab                         179067
# Downtown Dubai                       137620
# Motor City                            82173
# IMG World Adventures                  64268
# Burj Khalifa                          56842
# Dubai International Airport           36629
# Expo 2020 Site                        22653
# Dubai Cycling Course                  11091
# Al Makhtoum International Airport      3183
# Global Village                         2449
# Dubai Parks and Resorts                1879
# Jabel Ali                                 2
# Name: count, dtype: int64

# %%
flats_df18['nearest_landmark_en'] = flats_df18.nearest_landmark_en.fillna('__MISSING__')

# %%
flats_df18.isna().mean() * 100
# Out:
# trans_group_en         0.00000
# procedure_name_en      0.00000
# reg_type_id            0.00000
# reg_type_en            0.00000
# building_name_en       0.00000
# project_name_en        0.00000
# master_project_en      0.00000
# nearest_landmark_en    0.00000
# nearest_metro_en      23.04104
# nearest_mall_en       23.52439
# has_parking            0.00000
# procedure_area         0.00000
# meter_sale_price       0.00000
# rent_value            97.86005
# meter_rent_price      97.86005
# parsed_date            0.00000
# area_name_en           0.00000
# rooms_num              0.15968
# actual_worth_log       0.00000
# dtype: float64

# %%
flats_df18['nearest_landmark_en'] = flats_df18.nearest_landmark_en.fillna('__MISSING__')
flats_df18['nearest_metro_en'] = flats_df18.nearest_metro_en.fillna('__MISSING__')
flats_df18['nearest_mall_en'] = flats_df18.nearest_mall_en.fillna('__MISSING__')

# %%
flats_df18.isna().mean() * 100
# Out:
# trans_group_en         0.00000
# procedure_name_en      0.00000
# reg_type_id            0.00000
# reg_type_en            0.00000
# building_name_en       0.00000
# project_name_en        0.00000
# master_project_en      0.00000
# nearest_landmark_en    0.00000
# nearest_metro_en       0.00000
# nearest_mall_en        0.00000
# has_parking            0.00000
# procedure_area         0.00000
# meter_sale_price       0.00000
# rent_value            97.86005
# meter_rent_price      97.86005
# parsed_date            0.00000
# area_name_en           0.00000
# rooms_num              0.15968
# actual_worth_log       0.00000
# dtype: float64

# %%
flats_df19 = flats_df18.drop(columns=['rent_value', 'meter_rent_price'])
flats_df19.isna().mean() * 100
# Out:
# trans_group_en        0.00000
# procedure_name_en     0.00000
# reg_type_id           0.00000
# reg_type_en           0.00000
# building_name_en      0.00000
# project_name_en       0.00000
# master_project_en     0.00000
# nearest_landmark_en   0.00000
# nearest_metro_en      0.00000
# nearest_mall_en       0.00000
# has_parking           0.00000
# procedure_area        0.00000
# meter_sale_price      0.00000
# parsed_date           0.00000
# area_name_en          0.00000
# rooms_num             0.15968
# actual_worth_log      0.00000
# dtype: float64

# %%
flats_df20 = flats_df19[~flats_df19['rooms_num'].isna()]
df_status(flats_df19)
df_status(flats_df20)
# Out:
# 953,759 Samples & 17 Features
# 952,236 Samples & 17 Features

# %%
flats_df20[flats_df20.rooms_num.isna()].head(10)
# Out:
# Empty DataFrame
# Columns: [trans_group_en, procedure_name_en, reg_type_id, reg_type_en, building_name_en, project_name_en, master_project_en, nearest_landmark_en, nearest_metro_en, nearest_mall_en, has_parking, procedure_area, meter_sale_price, parsed_date, area_name_en, rooms_num, actual_worth_log]
# Index: []

# %% [markdown]
# ## Normalization for features

# %%
numerical_columns = flats_df20.select_dtypes(exclude=['str']).columns
numerical_columns
# Out:
# Index(['reg_type_id', 'has_parking', 'procedure_area', 'meter_sale_price',
#        'parsed_date', 'rooms_num', 'actual_worth_log'],
#       dtype='str')

# %%
# reg_type_id and has_parking are fine.

# %%
flats_df20.procedure_area.value_counts()
# Out:
# procedure_area
# 45.00000     4010
# 68.00000     3216
# 67.00000     2740
# 90.00000     2243
# 69.00000     2192
#              ...
# 117.35000       1
# 265.65000       1
# 360.86000       1
# 290.60000       1
# 171.69000       1
# Name: count, Length: 24144, dtype: int64

# %%
flats_df20.procedure_area.skew()
# Out:
# np.float64(144.04525700845068)

# %%
flats_df20.procedure_area.describe()
# Out:
# count   952,236.00000
# mean         97.03538
# std          68.24905
# min           0.01000
# 25%          62.13000
# 50%          81.85000
# 75%         121.14000
# max      35,117.33000
# Name: procedure_area, dtype: float64

# %%
flats_df20.procedure_area.quantile(0.8)
flats_df21 = flats_df20[(flats_df20.procedure_area < flats_df20.procedure_area.quantile(0.99)) &
                        (flats_df20.procedure_area > flats_df20.procedure_area.quantile(0.001))]
flats_df21.procedure_area.skew()
# Out:
# np.float64(1.1476566167838285)

# %%
# flats_df22 = flats_df21.drop(columns=['rooms_en'])
# len(flats_df22)

# %% [markdown]
# ## Handle Date

# %%
flats_df21.parsed_date.describe()
# Out:
# count                        941744
# mean     2020-04-09 01:39:17.899387
# min             2003-06-02 00:00:00
# 25%             2015-08-24 00:00:00
# 50%             2022-10-27 00:00:00
# 75%             2024-10-22 00:00:00
# max             2026-02-17 00:00:00
# Name: parsed_date, dtype: object

# %%
flats_df21.parsed_date.min()
# Out:
# Timestamp('2003-06-02 00:00:00')

# %%
reference_date = flats_df21.parsed_date.min()
flats_df21['days_since_reference_date'] = (flats_df21.parsed_date - reference_date).dt.days
flats_df21[['parsed_date', 'days_since_reference_date']]
# flats_df22 = flats_df21.drop(columns=['parsed_date'])
# len(flats_df22)
# Out:
#         parsed_date  days_since_reference_date
# 370      2016-02-15                       4641
# 372      2018-05-01                       5447
# 379      2024-01-16                       7533
# 380      2024-05-07                       7645
# 381      2024-02-29                       7577
# ...             ...                        ...
# 1665082  2026-01-09                       8257
# 1665083  2026-01-14                       8262
# 1665084  2026-01-20                       8268
# 1665093  2025-08-01                       8096
# 1665107  2023-10-20                       7445
#
# [941744 rows x 2 columns]

# %%
flats_df21.days_since_reference_date.skew()
# Out:
# np.float64(-0.7541152948490781)

# %%
# flats_df21.head()
# flats_df22 = flats_df21.drop(columns='parsed_date')
flats_df22 = flats_df21
df_status(flats_df22)
# Out:
# 941,744 Samples & 18 Features

# %%
flats_df22['days_since_reference_date'].describe()
# Out:
# count   941,744.00000
# mean      6,156.06896
# std       1,999.56190
# min           0.00000
# 25%       4,466.00000
# 50%       7,087.00000
# 75%       7,813.00000
# max       8,296.00000
# Name: days_since_reference_date, dtype: float64

# %%
numerical_columns = flats_df18.select_dtypes(exclude=['object']).columns
numerical_columns
# Out:
# Index(['reg_type_id', 'has_parking', 'procedure_area', 'meter_sale_price',
#        'rent_value', 'meter_rent_price', 'parsed_date', 'rooms_num',
#        'actual_worth_log'],
#       dtype='str')

# %%
flats_df22.procedure_area.describe()
# flats_df18.skew()
# Out:
# count   941,744.00000
# mean         93.94863
# std          47.35313
# min          27.39000
# 25%          61.89000
# 50%          81.34000
# 75%         119.84000
# max         297.18000
# Name: procedure_area, dtype: float64

# %%
# flats_df22.procedure_area.skew()
# flats_df18['procedure_area_log'] = np.log1p(flats_df18['procedure_area'])

# %%
# flats_df19 = flats_df18.drop(columns=['procedure_area'])

# %%
flats_df22.days_since_reference_date.describe()
# Out:
# count   941,744.00000
# mean      6,156.06896
# std       1,999.56190
# min           0.00000
# 25%       4,466.00000
# 50%       7,087.00000
# 75%       7,813.00000
# max       8,296.00000
# Name: days_since_reference_date, dtype: float64

# %%
flats_df22.days_since_reference_date.skew()
# Out:
# np.float64(-0.7541152948490781)

# %%
flats_df22.isna().sum()
# Out:
# trans_group_en               0
# procedure_name_en            0
# reg_type_id                  0
# reg_type_en                  0
# building_name_en             0
# project_name_en              0
# master_project_en            0
# nearest_landmark_en          0
# nearest_metro_en             0
# nearest_mall_en              0
# has_parking                  0
# procedure_area               0
# meter_sale_price             0
# parsed_date                  0
# area_name_en                 0
# rooms_num                    0
# actual_worth_log             0
# days_since_reference_date    0
# dtype: int64

# %%
flats_df22.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 941744 entries, 370 to 1665107
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   trans_group_en             941744 non-null  str
#  1   procedure_name_en          941744 non-null  str
#  2   reg_type_id                941744 non-null  int64
#  3   reg_type_en                941744 non-null  str
#  4   building_name_en           941744 non-null  str
#  5   project_name_en            941744 non-null  str
#  6   master_project_en          941744 non-null  str
#  7   nearest_landmark_en        941744 non-null  str
#  8   nearest_metro_en           941744 non-null  str
#  9   nearest_mall_en            941744 non-null  str
#  10  has_parking                941744 non-null  int64
#  11  procedure_area             941744 non-null  float64
#  12  meter_sale_price           941744 non-null  float64
#  13  parsed_date                941744 non-null  datetime64[us]
#  14  area_name_en               941744 non-null  str
#  15  rooms_num                  941744 non-null  float64
#  16  actual_worth_log           941744 non-null  float64
#  17  days_since_reference_date  941744 non-null  int64
# dtypes: datetime64[us](1), float64(4), int64(3), str(10)
# memory usage: 136.5 MB

# %%
flats_df23 = flats_df22.copy()

# %%
# flats_df23 = flats_df22.drop(columns='meter_sale_price')

# %%
df_status(flats_df23)
# Out:
# 941,744 Samples & 18 Features

# %%
categorical_columns = flats_df23.select_dtypes(include=['str']).columns
for col in categorical_columns:
    print(f"Unique counts of {col} is {flats_df23[col].nunique()}")
# Out:
# Unique counts of trans_group_en is 2
# Unique counts of procedure_name_en is 10
# Unique counts of reg_type_en is 2
# Unique counts of building_name_en is 4278
# Unique counts of project_name_en is 3053
# Unique counts of master_project_en is 216
# Unique counts of nearest_landmark_en is 14
# Unique counts of nearest_metro_en is 39
# Unique counts of nearest_mall_en is 6
# Unique counts of area_name_en is 72

# %%
flats_df23.building_name_en.value_counts()
# Out:
# building_name_en
# Seven City JLT                   3516
# PRINCESS TOWER                   2709
# Burj Khalifa                     2700
# Marina Pinnacle                  2536
# ELITE RESIDENCE                  2359
#                                  ...
# Barari Parkview by Al Mawared       1
# Mirdad 2                            1
# AMBER                               1
# The S Tower                         1
# Frond/JHFTA                         1
# Name: count, Length: 4278, dtype: int64

# %%
building_value_counts = flats_df23.building_name_en.value_counts()
type(building_value_counts)
# Out:
# pandas.Series

# %%
len(building_value_counts[building_value_counts < 10])
# Out:
# 316

# %%
rare_buildings = building_value_counts[building_value_counts < 10]
rare_buildings.index.tolist()[:10]
# Out:
# ['URBANA III STACKED HOUSE BLOCK-24',
#  'URBANA STACKED HOUSE BLOCK-22',
#  'C29',
#  'Al Waha 26',
#  'URBANA III STACKED HOUSE BLOCK-40',
#  'C39',
#  'Keturah G1',
#  'C32',
#  'S4-09A7',
#  'C31']

# %%
flats_df24 = flats_df23.copy()
flats_df24.building_name_en = flats_df24.building_name_en.apply(lambda x: 'Rare' if x in rare_buildings else x)

# %%
flats_df24.building_name_en.value_counts()
# Out:
# building_name_en
# Seven City JLT                       3516
# PRINCESS TOWER                       2709
# Burj Khalifa                         2700
# Marina Pinnacle                      2536
# ELITE RESIDENCE                      2359
#                                      ...
# URBANA II STACKED HOUSE BLOCK-20       10
# Saddlewood Park                        10
# URBANA III STACKED HOUSE BLOCK-07      10
# C48                                    10
# Greenside Residence-Tower C            10
# Name: count, Length: 3963, dtype: int64

# %%
flats_df24.head(2)
# Out:
#     trans_group_en procedure_name_en  reg_type_id          reg_type_en  \
# 370          Sales              Sell            1  Existing Properties
# 372          Sales              Sell            1  Existing Properties
#
#     building_name_en project_name_en master_project_en  \
# 370    EMAAR TOWER 1   EMAAR TOWER 1     EMAAR TOWER 1
# 372    EMAAR TOWER 2   EMAAR TOWER 2     EMAAR TOWER 2
#
#              nearest_landmark_en        nearest_metro_en nearest_mall_en  \
# 370  Dubai International Airport  Al Rigga Metro Station      Dubai Mall
# 372  Dubai International Airport  Al Rigga Metro Station      Dubai Mall
#
#      has_parking  procedure_area  meter_sale_price parsed_date  \
# 370            1        85.75000      11,953.35000  2016-02-15
# 372            1       161.37000       7,436.33000  2018-05-01
#
#        area_name_en  rooms_num  actual_worth_log  days_since_reference_date
# 370  Rega Al Buteen    1.00000          13.84020                       4641
# 372  Rega Al Buteen    3.00000          13.99783                       5447

# %% [markdown]
# # SPLIT

# %%
flats_df25 = flats_df24.sort_values("parsed_date").reset_index(drop=True)
flats_df25.head()
# Out:
#   trans_group_en        procedure_name_en  reg_type_id          reg_type_en  \
# 0          Sales  Sell - Pre registration            0  Off-Plan Properties
# 1          Sales  Sell - Pre registration            0  Off-Plan Properties
# 2          Sales  Sell - Pre registration            0  Off-Plan Properties
# 3          Sales  Sell - Pre registration            0  Off-Plan Properties
# 4          Sales  Sell - Pre registration            0  Off-Plan Properties
#
#     building_name_en    project_name_en master_project_en  \
# 0  THE WIND TOWER II  THE WIND TOWER II  Jumeirah Islands
# 1      GOLDEN MILE 4        GOLDEN MILE     Palm Jumeirah
# 2      GOLDEN MILE 1        GOLDEN MILE     Palm Jumeirah
# 3      GOLDEN MILE 3        GOLDEN MILE     Palm Jumeirah
# 4      GOLDEN MILE 1        GOLDEN MILE     Palm Jumeirah
#
#             nearest_landmark_en       nearest_metro_en nearest_mall_en  \
# 0  Sports City Swimming Academy  Jumeirah Lakes Towers     Marina Mall
# 1                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 2                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 3                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 4                  Burj Al Arab          Palm Jumeirah     Marina Mall
#
#    has_parking  procedure_area  meter_sale_price parsed_date  \
# 0            1       124.50000       6,501.65000  2003-06-02
# 1            1       175.29000       7,986.76000  2004-05-24
# 2            1       119.68000       7,302.81000  2004-05-25
# 3            1       167.19000       8,971.83000  2004-05-31
# 4            1       167.94000       7,070.98000  2004-06-07
#
#        area_name_en  rooms_num  actual_worth_log  days_since_reference_date
# 0  Al Thanyah Fifth    2.00000          13.60412                          0
# 1     Palm Jumeirah    2.00000          14.15198                        357
# 2     Palm Jumeirah    1.00000          13.68084                        358
# 3     Palm Jumeirah    2.00000          14.22098                        364
# 4     Palm Jumeirah    2.00000          13.98736                        371

# %%
flats_df26 = flats_df25.drop(columns='reg_type_id')
flats_df26
# Out:
#        trans_group_en        procedure_name_en          reg_type_en  \
# 0               Sales  Sell - Pre registration  Off-Plan Properties
# 1               Sales  Sell - Pre registration  Off-Plan Properties
# 2               Sales  Sell - Pre registration  Off-Plan Properties
# 3               Sales  Sell - Pre registration  Off-Plan Properties
# 4               Sales  Sell - Pre registration  Off-Plan Properties
# ...               ...                      ...                  ...
# 941739          Sales                     Sell  Existing Properties
# 941740          Sales  Sell - Pre registration  Off-Plan Properties
# 941741          Sales  Sell - Pre registration  Off-Plan Properties
# 941742          Sales  Sell - Pre registration  Off-Plan Properties
# 941743          Sales                     Sell  Existing Properties
#
#                    building_name_en    project_name_en  \
# 0                 THE WIND TOWER II  THE WIND TOWER II
# 1                     GOLDEN MILE 4        GOLDEN MILE
# 2                     GOLDEN MILE 1        GOLDEN MILE
# 3                     GOLDEN MILE 3        GOLDEN MILE
# 4                     GOLDEN MILE 1        GOLDEN MILE
# ...                             ...                ...
# 941739                         L-07               L-07
# 941740              Project Maybach    Project Maybach
# 941741             Waada - Altura 1   Waada - Altura 1
# 941742  ELLINGTON SANDS I - TOWER B  ELLINGTON SANDS I
# 941743                   ROKANE G24         ROKANE G24
#
#                   master_project_en           nearest_landmark_en  \
# 0                  Jumeirah Islands  Sports City Swimming Academy
# 1                     Palm Jumeirah                  Burj Al Arab
# 2                     Palm Jumeirah                  Burj Al Arab
# 3                     Palm Jumeirah                  Burj Al Arab
# 4                     Palm Jumeirah                  Burj Al Arab
# ...                             ...                           ...
# 941739   International City Phase 1                   __MISSING__
# 941740  Meydan Racecourse Community                Downtown Dubai
# 941741          Dubai World Central                   __MISSING__
# 941742                   Palm Deira                   __MISSING__
# 941743   International City Phase 3                   __MISSING__
#
#                nearest_metro_en     nearest_mall_en  has_parking  \
# 0         Jumeirah Lakes Towers         Marina Mall            1
# 1                 Palm Jumeirah         Marina Mall            1
# 2                 Palm Jumeirah         Marina Mall            1
# 3                 Palm Jumeirah         Marina Mall            1
# 4                 Palm Jumeirah         Marina Mall            1
# ...                         ...                 ...          ...
# 941739  Rashidiya Metro Station  City Centre Mirdif            0
# 941740      Creek Metro Station          Dubai Mall            1
# 941741              __MISSING__         __MISSING__            1
# 941742              __MISSING__         __MISSING__            1
# 941743  Rashidiya Metro Station  City Centre Mirdif            1
#
#         procedure_area  meter_sale_price parsed_date        area_name_en  \
# 0            124.50000       6,501.65000  2003-06-02    Al Thanyah Fifth
# 1            175.29000       7,986.76000  2004-05-24       Palm Jumeirah
# 2            119.68000       7,302.81000  2004-05-25       Palm Jumeirah
# 3            167.19000       8,971.83000  2004-05-31       Palm Jumeirah
# 4            167.94000       7,070.98000  2004-06-07       Palm Jumeirah
# ...                ...               ...         ...                 ...
# 941739        46.00000       7,065.22000  2026-02-17     Al Warsan First
# 941740        35.28000      38,888.89000  2026-02-17  Nad Al Shiba First
# 941741        37.28000      12,473.18000  2026-02-17   Madinat Al Mataar
# 941742       128.68000      29,016.38000  2026-02-17          Palm Deira
# 941743        41.09000      12,411.78000  2026-02-17       Warsan Fourth
#
#         rooms_num  actual_worth_log  days_since_reference_date
# 0         2.00000          13.60412                          0
# 1         2.00000          14.15198                        357
# 2         1.00000          13.68084                        358
# 3         2.00000          14.22098                        364
# 4         2.00000          13.98736                        371
# ...           ...               ...                        ...
# 941739    1.00000          12.69158                       8296
# 941740    1.00000          14.13178                       8296
# 941741    1.00000          13.04979                       8296
# 941742    2.00000          15.13294                       8296
# 941743    1.00000          13.14217                       8296
#
# [941744 rows x 17 columns]

# %%
prices = np.expm1(flats_df26.actual_worth_log)
prices.describe()
# Out:
# count     941,744.00000
# mean    1,433,169.42741
# std     1,108,746.08173
# min       300,016.00000
# 25%       686,109.00000
# 50%     1,100,000.00000
# 75%     1,800,000.00000
# max     8,549,548.00000
# Name: actual_worth_log, dtype: float64

# %%
df_status(flats_df26)
# Out:
# 941,744 Samples & 17 Features

# %%
flats_df26.columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'has_parking', 'procedure_area', 'meter_sale_price', 'parsed_date',
#        'area_name_en', 'rooms_num', 'actual_worth_log',
#        'days_since_reference_date'],
#       dtype='str')

# %%
flats_df26['year'] = flats_df26['parsed_date'].dt.year
flats_df26['month'] = flats_df26['parsed_date'].dt.month
flats_df26['quarter'] = flats_df26['parsed_date'].dt.quarter
# flats_df26['day_of_week'] = flats_df26['parsed_date'].dt.dayofweek

# %%
flats_df26.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 941744 entries, 0 to 941743
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   trans_group_en             941744 non-null  str
#  1   procedure_name_en          941744 non-null  str
#  2   reg_type_en                941744 non-null  str
#  3   building_name_en           941744 non-null  str
#  4   project_name_en            941744 non-null  str
#  5   master_project_en          941744 non-null  str
#  6   nearest_landmark_en        941744 non-null  str
#  7   nearest_metro_en           941744 non-null  str
#  8   nearest_mall_en            941744 non-null  str
#  9   has_parking                941744 non-null  int64
#  10  procedure_area             941744 non-null  float64
#  11  meter_sale_price           941744 non-null  float64
#  12  parsed_date                941744 non-null  datetime64[us]
#  13  area_name_en               941744 non-null  str
#  14  rooms_num                  941744 non-null  float64
#  15  actual_worth_log           941744 non-null  float64
#  16  days_since_reference_date  941744 non-null  int64
#  17  year                       941744 non-null  int32
#  18  month                      941744 non-null  int32
#  19  quarter                    941744 non-null  int32
# dtypes: datetime64[us](1), float64(4), int32(3), int64(2), str(10)
# memory usage: 132.9 MB

# %%
cat_cols = [
    'trans_group_en', 'procedure_name_en', 'reg_type_en', 
    'building_name_en', 'project_name_en', 'master_project_en', 
    'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en', 'area_name_en'
]

# %%
flats_df26.head()
# Out:
#   trans_group_en        procedure_name_en          reg_type_en  \
# 0          Sales  Sell - Pre registration  Off-Plan Properties
# 1          Sales  Sell - Pre registration  Off-Plan Properties
# 2          Sales  Sell - Pre registration  Off-Plan Properties
# 3          Sales  Sell - Pre registration  Off-Plan Properties
# 4          Sales  Sell - Pre registration  Off-Plan Properties
#
#     building_name_en    project_name_en master_project_en  \
# 0  THE WIND TOWER II  THE WIND TOWER II  Jumeirah Islands
# 1      GOLDEN MILE 4        GOLDEN MILE     Palm Jumeirah
# 2      GOLDEN MILE 1        GOLDEN MILE     Palm Jumeirah
# 3      GOLDEN MILE 3        GOLDEN MILE     Palm Jumeirah
# 4      GOLDEN MILE 1        GOLDEN MILE     Palm Jumeirah
#
#             nearest_landmark_en       nearest_metro_en nearest_mall_en  \
# 0  Sports City Swimming Academy  Jumeirah Lakes Towers     Marina Mall
# 1                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 2                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 3                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 4                  Burj Al Arab          Palm Jumeirah     Marina Mall
#
#    has_parking  procedure_area  meter_sale_price parsed_date  \
# 0            1       124.50000       6,501.65000  2003-06-02
# 1            1       175.29000       7,986.76000  2004-05-24
# 2            1       119.68000       7,302.81000  2004-05-25
# 3            1       167.19000       8,971.83000  2004-05-31
# 4            1       167.94000       7,070.98000  2004-06-07
#
#        area_name_en  rooms_num  actual_worth_log  days_since_reference_date  \
# 0  Al Thanyah Fifth    2.00000          13.60412                          0
# 1     Palm Jumeirah    2.00000          14.15198                        357
# 2     Palm Jumeirah    1.00000          13.68084                        358
# 3     Palm Jumeirah    2.00000          14.22098                        364
# 4     Palm Jumeirah    2.00000          13.98736                        371
#
#    year  month  quarter
# 0  2003      6        2
# 1  2004      5        2
# 2  2004      5        2
# 3  2004      5        2
# 4  2004      6        2

# %%
# X.head()

# %%
flats_df26 = flats_df26.sort_values('parsed_date')

# %%
flats_df26.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 941744 entries, 0 to 941743
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   trans_group_en             941744 non-null  str
#  1   procedure_name_en          941744 non-null  str
#  2   reg_type_en                941744 non-null  str
#  3   building_name_en           941744 non-null  str
#  4   project_name_en            941744 non-null  str
#  5   master_project_en          941744 non-null  str
#  6   nearest_landmark_en        941744 non-null  str
#  7   nearest_metro_en           941744 non-null  str
#  8   nearest_mall_en            941744 non-null  str
#  9   has_parking                941744 non-null  int64
#  10  procedure_area             941744 non-null  float64
#  11  meter_sale_price           941744 non-null  float64
#  12  parsed_date                941744 non-null  datetime64[us]
#  13  area_name_en               941744 non-null  str
#  14  rooms_num                  941744 non-null  float64
#  15  actual_worth_log           941744 non-null  float64
#  16  days_since_reference_date  941744 non-null  int64
#  17  year                       941744 non-null  int32
#  18  month                      941744 non-null  int32
#  19  quarter                    941744 non-null  int32
# dtypes: datetime64[us](1), float64(4), int32(3), int64(2), str(10)
# memory usage: 140.1 MB

# %%
cat_cols = flats_df26.select_dtypes(include='str')
for col in cat_cols:
    flats_df26[col] = flats_df26[col].astype('category')

# %%
# Sort by date to ensure the split is chronological

flats_df27 = flats_df26.drop(columns='parsed_date')
X = flats_df27.drop(columns=['actual_worth_log', 'meter_sale_price'])
y = flats_df27['actual_worth_log']

# Use the last 15% of data as the test set
split_idx = int(len(flats_df27) * 0.85)

X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

# %%
X_train.head()
# Out:
#   trans_group_en        procedure_name_en          reg_type_en  \
# 0          Sales  Sell - Pre registration  Off-Plan Properties
# 1          Sales  Sell - Pre registration  Off-Plan Properties
# 2          Sales  Sell - Pre registration  Off-Plan Properties
# 3          Sales  Sell - Pre registration  Off-Plan Properties
# 4          Sales  Sell - Pre registration  Off-Plan Properties
#
#     building_name_en    project_name_en master_project_en  \
# 0  THE WIND TOWER II  THE WIND TOWER II  Jumeirah Islands
# 1      GOLDEN MILE 4        GOLDEN MILE     Palm Jumeirah
# 2      GOLDEN MILE 1        GOLDEN MILE     Palm Jumeirah
# 3      GOLDEN MILE 3        GOLDEN MILE     Palm Jumeirah
# 4      GOLDEN MILE 1        GOLDEN MILE     Palm Jumeirah
#
#             nearest_landmark_en       nearest_metro_en nearest_mall_en  \
# 0  Sports City Swimming Academy  Jumeirah Lakes Towers     Marina Mall
# 1                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 2                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 3                  Burj Al Arab          Palm Jumeirah     Marina Mall
# 4                  Burj Al Arab          Palm Jumeirah     Marina Mall
#
#    has_parking  procedure_area      area_name_en  rooms_num  \
# 0            1       124.50000  Al Thanyah Fifth    2.00000
# 1            1       175.29000     Palm Jumeirah    2.00000
# 2            1       119.68000     Palm Jumeirah    1.00000
# 3            1       167.19000     Palm Jumeirah    2.00000
# 4            1       167.94000     Palm Jumeirah    2.00000
#
#    days_since_reference_date  year  month  quarter
# 0                          0  2003      6        2
# 1                        357  2004      5        2
# 2                        358  2004      5        2
# 3                        364  2004      5        2
# 4                        371  2004      6        2

# %%
import xgboost as xgb

# %%
model = xgb.XGBRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.80,
    n_jobs=-1,
    tree_method='hist',
    early_stopping_rounds=50,
    objective='reg:squarederror',
    enable_categorical=True
)

# Fit the model
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=100
)
# Out:
# [0]	validation_0-rmse:0.62479
# [100]	validation_0-rmse:0.25257
# [200]	validation_0-rmse:0.24449
# [300]	validation_0-rmse:0.24287
# [400]	validation_0-rmse:0.24164
# [500]	validation_0-rmse:0.24119
# [600]	validation_0-rmse:0.24100
# [700]	validation_0-rmse:0.24074
# [719]	validation_0-rmse:0.24074
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=50,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
from sklearn.metrics import mean_absolute_error
# Predict
preds_log = model.predict(X_test)

# Convert back from Log to actual Price
preds_actual = np.exp(preds_log)
y_test_actual = np.exp(y_test)

# Calculate Mean Absolute Error (Average error in price)
mae = mean_absolute_error(y_test_actual, preds_actual)
print(f"Average Prediction Error: {mae:.2f}")

# Feature Importance: See what actually drives the price
xgb.plot_importance(model, max_num_features=10)
# Out:
# Average Prediction Error: 280488.64
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
from sklearn.metrics import median_absolute_error
med_ae = median_absolute_error(y_test_actual, preds_actual)
print(f"Median Error: {med_ae}")
# Out:
# Median Error: 133758.43749999988

# %%
prices = np.expm1(y)
prices
# Out:
# 0          809,455.00000
# 1        1,400,000.00000
# 2          874,000.00000
# 3        1,500,000.00000
# 4        1,187,500.00000
#                ...
# 941240     450,000.00000
# 941241   3,819,000.00000
# 941242     960,000.00000
# 941233   1,428,000.00000
# 941743     510,000.00000
# Name: actual_worth_log, Length: 941744, dtype: float64

# %%
median_price = prices.median()
print("Median price:", median_price)
# Out:
# Median price: 1099999.9999999998

# %%
relative_error = (med_ae / median_price) * 100
print(f"Relative error: {relative_error:.2f}%")
# Out:
# Relative error: 12.16%

# %%
X_train.columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'has_parking', 'procedure_area', 'area_name_en', 'rooms_num',
#        'days_since_reference_date', 'year', 'month', 'quarter'],
#       dtype='str')

# %%
X_train[X_train['days_since_reference_date'] == 0]
# Out:
#   trans_group_en        procedure_name_en          reg_type_en  \
# 0          Sales  Sell - Pre registration  Off-Plan Properties
#
#     building_name_en    project_name_en master_project_en  \
# 0  THE WIND TOWER II  THE WIND TOWER II  Jumeirah Islands
#
#             nearest_landmark_en       nearest_metro_en nearest_mall_en  \
# 0  Sports City Swimming Academy  Jumeirah Lakes Towers     Marina Mall
#
#    has_parking  procedure_area      area_name_en  rooms_num  \
# 0            1       124.50000  Al Thanyah Fifth    2.00000
#
#    days_since_reference_date  year  month  quarter
# 0                          0  2003      6        2

# %%
from datetime import datetime, date

def get_date_features(date_str=None):
    """
    Returns:
    - days difference from 2003-06-02
    - year
    - month
    - quarter
    """

    base_date = date(2003, 6, 2)

    # Use today's date if no date string provided
    if not date_str:
        input_date = date.today()
    else:
        input_date = datetime.strptime(date_str, "%d-%m-%Y").date()

    days_diff = (input_date - base_date).days
    year = input_date.year
    month = input_date.month
    quarter = (month - 1) // 3 + 1

    return days_diff, year, month, quarter


# Examples
print(get_date_features("15-10-2020"))
print(get_date_features())        # uses today's date
print(get_date_features(None))    # also uses today's date
# Out:
# (6345, 2020, 10, 4)
# (8313, 2026, 3, 1)
# (8313, 2026, 3, 1)

# %%
X_train.columns
# Out:
# Index(['trans_group_en', 'procedure_name_en', 'reg_type_en',
#        'building_name_en', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'has_parking', 'procedure_area', 'area_name_en', 'rooms_num',
#        'days_since_reference_date', 'year', 'month', 'quarter'],
#       dtype='str')

# %%
# def predict_price(trans_group_en, procedure_name_en, reg_type_en, building_name_en,
#                   procedure_area_en, area_name_en, rooms_num,
#                   project_name_en = None, master_project_en = None, nearest_landmark_en = None,
#                   nearest_metro_en = None, nearest_mall_en = None, has_parking = 0,
#                   transaction_date = None):
#     days_since_reference_date, year, month, quarter = get_date_features(transaction_date)
#     x = np.array([[trans_group_en, procedure_name_en, reg_type_en, building_name_en,
#                  project_name_en, master_project_en, nearest_landmark_en, nearest_metro_en, 
#                   nearest_mall_en, has_parking, procedure_area_en, area_name_en, rooms_num, 
#                  days_since_reference_date, year, month, quarter]])
#     return model.predict(x)

# %%
def predict_price(trans_group_en, procedure_name_en, reg_type_en, building_name_en,
                  procedure_area, area_name_en, rooms_num,
                  project_name_en = None, master_project_en = None, nearest_landmark_en = None,
                  nearest_metro_en = None, nearest_mall_en = None, has_parking = 0,
                  transaction_date = None):
    days_since_reference_date, year, month, quarter = get_date_features(transaction_date)
    x = pd.DataFrame([{
            "trans_group_en": trans_group_en,
            "procedure_name_en": procedure_name_en,
            "reg_type_en": reg_type_en,
            "building_name_en": building_name_en,
            "project_name_en": project_name_en,
            "master_project_en": master_project_en,
            "nearest_landmark_en": nearest_landmark_en,
            "nearest_metro_en": nearest_metro_en,
            "nearest_mall_en": nearest_mall_en,
            "has_parking": has_parking,
            "procedure_area": procedure_area,
            "area_name_en": area_name_en,
            "rooms_num": rooms_num,
            "days_since_reference_date": days_since_reference_date,
            "year": year,
            "month": month,
            "quarter": quarter
        }])

    cat_cols = x.select_dtypes(include='str')
    for col in cat_cols:
        x[col] = x[col].astype('category')
    
    log_price = model.predict(x)
    return np.expm1(log_price[0])

# %%
flats

# %%
print(format_num(predict_price('Sales', 'Sell - Pre registration', 'Off-Plan Properties', 'Seven City JLT', 100, 'Al Thanyah Fifth', 
                    2, 'SEVEN CITY JLT', 'Jumeirah Islands', 'Burj Al Arab', 'Damac Properties', 
                    'Marina Mall', 1, '01-03-2026')))


# Mtrs, No. of bedrooms, building name
# Out:
# 1,885,065.0

# %%
flats_df2[flats_df2.building_name_en == 'Seven City JLT'].sort_values(by='parsed_date')[-10
# Out:
#            transaction_id  procedure_id  trans_group_id trans_group_en  \
# 1559273     3-120-2026-55           120               3          Gifts
# 986115    1-102-2026-6989           102               1          Sales
# 76215     1-102-2026-9649           102               1          Sales
# 1663950  1-102-2026-10380           102               1          Sales
# 648183   1-102-2026-10387           102               1          Sales
# 1663947  1-102-2026-13651           102               1          Sales
# 1559294  1-102-2026-16468           102               1          Sales
# 1637626  1-102-2026-16956           102               1          Sales
# 1194213  1-102-2026-16997           102               1          Sales
# 674311   1-102-2026-17047           102               1          Sales
#
#                procedure_name_en instance_date property_usage_en  reg_type_id  \
# 1559273   Grant Pre-Registration    20-01-2026       Residential            0
# 986115   Sell - Pre registration    21-01-2026       Residential            0
# 76215    Sell - Pre registration    28-01-2026       Residential            0
# 1663950  Sell - Pre registration    29-01-2026       Residential            0
# 648183   Sell - Pre registration    29-01-2026       Residential            0
# 1663947  Sell - Pre registration    09-02-2026       Residential            0
# 1559294  Sell - Pre registration    13-02-2026       Residential            0
# 1637626  Sell - Pre registration    16-02-2026       Residential            0
# 1194213  Sell - Pre registration    16-02-2026       Residential            0
# 674311   Sell - Pre registration    16-02-2026       Residential            0
#
#                  reg_type_en  area_id  ... has_parking procedure_area  \
# 1559273  Off-Plan Properties      350  ...           1       68.66000
# 986115   Off-Plan Properties      350  ...           1       37.41000
# 76215    Off-Plan Properties      350  ...           1       38.59000
# 1663950  Off-Plan Properties      350  ...           1       38.57000
# 648183   Off-Plan Properties      350  ...           1       38.57000
# 1663947  Off-Plan Properties      350  ...           1       38.58000
# 1559294  Off-Plan Properties      350  ...           1       38.59000
# 1637626  Off-Plan Properties      350  ...           1       38.59000
# 1194213  Off-Plan Properties      350  ...           1      141.24000
# 674311   Off-Plan Properties      350  ...           1       37.22000
#
#            actual_worth meter_sale_price rent_value meter_rent_price  \
# 1559273   900,007.00000     13,108.18000        NaN              NaN
# 986115    515,000.00000     13,766.37000        NaN              NaN
# 76215     560,000.00000     14,511.53000        NaN              NaN
# 1663950   550,000.00000     14,259.79000        NaN              NaN
# 648183    550,000.00000     14,259.79000        NaN              NaN
# 1663947   600,000.00000     15,552.10000        NaN              NaN
# 1559294   550,000.00000     14,252.40000        NaN              NaN
# 1637626   540,000.00000     13,993.26000        NaN              NaN
# 1194213 1,920,000.00000     13,593.88000        NaN              NaN
# 674311    623,000.00000     16,738.31000        NaN              NaN
#
#         no_of_parties_role_1 no_of_parties_role_2 no_of_parties_role_3  \
# 1559273              1.00000              1.00000              0.00000
# 986115               2.00000              1.00000              0.00000
# 76215                1.00000              1.00000              0.00000
# 1663950              1.00000              1.00000              0.00000
# 648183               1.00000              1.00000              0.00000
# 1663947              1.00000              1.00000              0.00000
# 1559294              1.00000              1.00000              0.00000
# 1637626              1.00000              1.00000              0.00000
# 1194213              2.00000              1.00000              0.00000
# 674311               1.00000              1.00000              0.00000
#
#          parsed_date
# 1559273   2026-01-20
# 986115    2026-01-21
# 76215     2026-01-28
# 1663950   2026-01-29
# 648183    2026-01-29
# 1663947   2026-02-09
# 1559294   2026-02-13
# 1637626   2026-02-16
# 1194213   2026-02-16
# 674311    2026-02-16
#
# [10 rows x 29 columns]

# %%
import pickle

with open('dubai_flats_prices.pickle', 'wb') as f:
    pickle.dump(model, f)
